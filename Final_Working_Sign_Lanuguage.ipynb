# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install playsound
# Out:
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py): started
#   Building wheel for playsound (setup.py): finished with status 'done'
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7090 sha256=0de435e41906f01c159636e600b44c39850986b127711edbb7a89851fc38f629
#   Stored in directory: c:\users\sarve\appdata\local\pip\cache\wheels\ba\39\54\c8f7ff9a88a644d3c58b4dec802d90b79a2e0fb2a6b884bf82
# Successfully built playsound
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0

# %%
import enchant
print(dir(enchant))
# Out:
# ['Broker', 'Dict', 'DictNotFoundError', 'DictWithPWL', 'Error', 'ProviderDesc', 'PyPWL', '_DOC_ERRORS', '_EnchantObject', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_broker', '_e', '_enchant', 'dict_exists', 'errors', 'get_default_language', 'get_enchant_version', 'get_param', 'get_user_config_dir', 'list_dicts', 'list_languages', 'os', 'pypwl', 'request_dict', 'request_pwl_dict', 'set_param', 'set_prefix_dir', 'utils', 'warnings']

# %%
import enchant
print(enchant.__file__)
# Out:
# C:\Users\sarve\anaconda3\envs\project\lib\site-packages\enchant\__init__.py

# %%
# !pip show pyenchant
# Out:
# Name: pyenchant
# Version: 3.2.2
# Summary: Python bindings for the Enchant spellchecking system
# Home-page: https://pyenchant.github.io/pyenchant/
# Author: Dimitri Merejkowsky
# Author-email: d.merej@gmail.com
# License: LGPL
# Location: c:\users\sarve\anaconda3\envs\project\lib\site-packages
# Requires:
# Required-by:

# %%
# !pip show cvzone
# Out:
# Name: cvzone
# Version: 1.6.1
# Summary: Computer Vision Helping Library
# Home-page: https://github.com/cvzone/cvzone.git
# Author: Computer Vision Zone
# Author-email: contact@computervision.zone
# License: MIT
# Location: c:\users\sarve\anaconda3\envs\project\lib\site-packages
# Requires: numpy, opencv-python
# Required-by:

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.31)
# Requirement already satisfied: hstspreload in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.1)
# Requirement already satisfied: sniffio in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Requirement already satisfied: chardet==3.* in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %% [markdown]
# # Model Running

# %%
# Importing Libraries
import numpy as np
import math
import cv2

import os, sys
import traceback
import pyttsx3
from keras.models import load_model
from cvzone.HandTrackingModule import HandDetector
from string import ascii_uppercase
import enchant
ddd=enchant.Dict("en-US")
hd = HandDetector(maxHands=1)
hd2 = HandDetector(maxHands=1)
import tkinter as tk
from PIL import Image, ImageTk
from googletrans import Translator


offset=29



class Application:

    def __init__(self):
        self.vs = cv2.VideoCapture(0)
        self.current_image = None
        self.model = load_model("D:\SEM8\Sign Language Project\Sign-Language-To-Text-and-Speech-Conversion-master\cnn8grps_rad1_model.h5")
        self.speak_engine=pyttsx3.init()
        self.speak_engine.setProperty("rate",100)
        voices=self.speak_engine.getProperty("voices")
        self.speak_engine.setProperty("voice",voices[0].id)


        self.ct = {}
        self.ct['blank'] = 0
        self.blank_flag = 0
        self.space_flag=False
        self.next_flag=True
        self.prev_char=""
        self.count=-1
        self.ten_prev_char=[]
        for i in range(10):
            self.ten_prev_char.append(" ")


        for i in ascii_uppercase:
            self.ct[i] = 0
        print("Loaded model from disk")


        self.root = tk.Tk()
        self.root.title("Sign Language To Text Conversion")
        self.root.protocol('WM_DELETE_WINDOW', self.destructor)
        self.root.geometry("1300x700")

        self.panel = tk.Label(self.root)
        self.panel.place(x=100, y=3, width=480, height=640)

        self.panel2 = tk.Label(self.root)  # initialize image panel
        self.panel2.place(x=700, y=115, width=400, height=400)

        self.T = tk.Label(self.root)
        self.T.place(x=60, y=5)
        self.T.config(text="Sign Language To Text Conversion", font=("Courier", 30, "bold"))

        self.panel3 = tk.Label(self.root)  # Current Symbol
        self.panel3.place(x=280, y=585)

        self.T1 = tk.Label(self.root)
        self.T1.place(x=10, y=580)
        self.T1.config(text="Character :", font=("Courier", 30, "bold"))

        self.panel5 = tk.Label(self.root)  # Sentence
        self.panel5.place(x=260, y=632)

        self.T3 = tk.Label(self.root)
        self.T3.place(x=10, y=632)
        self.T3.config(text="Sentence :", font=("Courier", 30, "bold"))

        self.T4 = tk.Label(self.root)
        self.T4.place(x=10, y=700)
        self.T4.config(text="Suggestions :", fg="red", font=("Courier", 30, "bold"))


        self.b1=tk.Button(self.root)
        self.b1.place(x=390,y=700)

        self.b2 = tk.Button(self.root)
        self.b2.place(x=590, y=700)

        self.b3 = tk.Button(self.root)
        self.b3.place(x=790, y=700)

        self.b4 = tk.Button(self.root)
        self.b4.place(x=990, y=700)

        self.speak = tk.Button(self.root)
        self.speak.place(x=1205, y=630)
        self.speak.config(text="Speak", font=("Courier", 20), wraplength=100, command=self.speak_fun)

        self.clear = tk.Button(self.root)
        self.clear.place(x=1105, y=630)
        self.clear.config(text="Clear", font=("Courier", 20), wraplength=100, command=self.clear_fun)



        # Add Translate button
        self.translate_button = tk.Button(self.root, text="Translate to Tamil", font=("Courier", 20), wraplength=150, command=self.translate_to_tamil)
        self.translate_button.place(x=1305, y=630)  # Adjusted position to be after Speak & Clear

        self.str = " "
        self.ccc=0
        self.word = " "
        self.current_symbol = "C"
        self.photo = "Empty"


        self.word1=" "
        self.word2 = " "
        self.word3 = " "
        self.word4 = " "

        self.video_loop()

    def translate_to_tamil(self):
        from googletrans import Translator
        translator = Translator()
        translated_text = translator.translate(self.str, src='en', dest='ta')  # 'ta' is Tamil
        
        # Replace the original sentence with the Tamil translation
        self.str = translated_text.text  # Update self.str with the translated text
        self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)  # Display Tamil text in the same label



    def video_loop(self):
        try:
            ok, frame = self.vs.read()
            cv2image = cv2.flip(frame, 1)
            if cv2image.any:
                hands = hd.findHands(cv2image, draw=False, flipType=True)
                cv2image_copy=np.array(cv2image)
                cv2image = cv2.cvtColor(cv2image, cv2.COLOR_BGR2RGB)
                self.current_image = Image.fromarray(cv2image)
                imgtk = ImageTk.PhotoImage(image=self.current_image)
                self.panel.imgtk = imgtk
                self.panel.config(image=imgtk)

                if hands[0]:
                    hand = hands[0]
                    map = hand[0]
                    x, y, w, h=map['bbox'] 
                    image = cv2image_copy[y - offset:y + h + offset, x - offset:x + w + offset]

                    white = cv2.imread("D:\SEM8\Sign Language Project\Sign-Language-To-Text-and-Speech-Conversion-master\white.jpg")
                    # img_final=img_final1=img_final2=0
                    if image.all:
                        handz = hd2.findHands(image, draw=False, flipType=True)
                        self.ccc += 1
                        if handz[0]:
                            hand = handz[0]
                            handmap=hand[0]
                            self.pts = handmap['lmList']
                            # x1,y1,w1,h1=hand['bbox']

                            os = ((400 - w) // 2) - 15
                            os1 = ((400 - h) // 2) - 15
                            for t in range(0, 4, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(5, 8, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(9, 12, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(13, 16, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(17, 20, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            cv2.line(white, (self.pts[5][0] + os, self.pts[5][1] + os1), (self.pts[9][0] + os, self.pts[9][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[9][0] + os, self.pts[9][1] + os1), (self.pts[13][0] + os, self.pts[13][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[13][0] + os, self.pts[13][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1),
                                     (0, 255, 0), 3)
                            cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[5][0] + os, self.pts[5][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1), (0, 255, 0),
                                     3)

                            for i in range(21):
                                cv2.circle(white, (self.pts[i][0] + os, self.pts[i][1] + os1), 2, (0, 0, 255), 1)

                            res=white
                            self.predict(res)

                            self.current_image2 = Image.fromarray(res)

                            imgtk = ImageTk.PhotoImage(image=self.current_image2)

                            self.panel2.imgtk = imgtk
                            self.panel2.config(image=imgtk)

                            self.panel3.config(text=self.current_symbol, font=("Courier", 30))

                            #self.panel4.config(text=self.word, font=("Courier", 30))



                            self.b1.config(text=self.word1, font=("Courier", 20), wraplength=825, command=self.action1)
                            self.b2.config(text=self.word2, font=("Courier", 20), wraplength=825,  command=self.action2)
                            self.b3.config(text=self.word3, font=("Courier", 20), wraplength=825,  command=self.action3)
                            self.b4.config(text=self.word4, font=("Courier", 20), wraplength=825,  command=self.action4)

                self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
        except Exception:
            print(Exception.__traceback__)
            hands = hd.findHands(cv2image, draw=False, flipType=True)
            cv2image_copy=np.array(cv2image)
            cv2image = cv2.cvtColor(cv2image, cv2.COLOR_BGR2RGB)
            self.current_image = Image.fromarray(cv2image)
            imgtk = ImageTk.PhotoImage(image=self.current_image)
            self.panel.imgtk = imgtk
            self.panel.config(image=imgtk)

            if hands:
                # #print(" --------- lmlist=",hands[1])
                hand = hands[0]
                x, y, w, h = hand['bbox']
                image = cv2image_copy[y - offset:y + h + offset, x - offset:x + w + offset]

                white = cv2.imread("D:\SEM8\Sign Language Project\Sign-Language-To-Text-and-Speech-Conversion-master\white.jpg")
                # img_final=img_final1=img_final2=0

                handz = hd2.findHands(image, draw=False, flipType=True)
                print(" ", self.ccc)
                self.ccc += 1
                if handz:
                    hand = handz[0]
                    self.pts = hand['lmList']
                    # x1,y1,w1,h1=hand['bbox']

                    os = ((400 - w) // 2) - 15
                    os1 = ((400 - h) // 2) - 15
                    for t in range(0, 4, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(5, 8, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(9, 12, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(13, 16, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(17, 20, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    cv2.line(white, (self.pts[5][0] + os, self.pts[5][1] + os1), (self.pts[9][0] + os, self.pts[9][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[9][0] + os, self.pts[9][1] + os1), (self.pts[13][0] + os, self.pts[13][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[13][0] + os, self.pts[13][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1),
                             (0, 255, 0), 3)
                    cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[5][0] + os, self.pts[5][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1), (0, 255, 0),
                             3)

                    for i in range(21):
                        cv2.circle(white, (self.pts[i][0] + os, self.pts[i][1] + os1), 2, (0, 0, 255), 1)

                    res=white
                    self.predict(res)

                    self.current_image2 = Image.fromarray(res)

                    imgtk = ImageTk.PhotoImage(image=self.current_image2)

                    self.panel2.imgtk = imgtk
                    self.panel2.config(image=imgtk)

                    self.panel3.config(text=self.current_symbol, font=("Courier", 30))

                    #self.panel4.config(text=self.word, font=("Courier", 30))



                    self.b1.config(text=self.word1, font=("Courier", 20), wraplength=825, command=self.action1)
                    self.b2.config(text=self.word2, font=("Courier", 20), wraplength=825,  command=self.action2)
                    self.b3.config(text=self.word3, font=("Courier", 20), wraplength=825,  command=self.action3)
                    self.b4.config(text=self.word4, font=("Courier", 20), wraplength=825,  command=self.action4)

            self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
        except Exception:
            print("==", traceback.format_exc())
        finally:
            self.root.after(1, self.video_loop)

    def distance(self,x,y):
        return math.sqrt(((x[0] - y[0]) ** 2) + ((x[1] - y[1]) ** 2))

    def action1(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word1.upper()


    def action2(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str=self.str[:idx_word]
        self.str=self.str+self.word2.upper()
        #self.str[idx_word:last_idx] = self.word2


    def action3(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word3.upper()



    def action4(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word4.upper()


    def speak_fun(self):
        self.speak_engine.say(self.str)
        self.speak_engine.runAndWait()


    def clear_fun(self):
        self.str=" "
        self.word1 = " "
        self.word2 = " "
        self.word3 = " "
        self.word4 = " "

    def predict(self, test_image):
        white=test_image
        white = white.reshape(1, 400, 400, 3)
        prob = np.array(self.model.predict(white)[0], dtype='float32')
        ch1 = np.argmax(prob, axis=0)
        prob[ch1] = 0
        ch2 = np.argmax(prob, axis=0)
        prob[ch2] = 0
        ch3 = np.argmax(prob, axis=0)
        prob[ch3] = 0

        pl = [ch1, ch2]

        # condition for [Aemnst]
        l = [[5, 2], [5, 3], [3, 5], [3, 6], [3, 0], [3, 2], [6, 4], [6, 1], [6, 2], [6, 6], [6, 7], [6, 0], [6, 5],
             [4, 1], [1, 0], [1, 1], [6, 3], [1, 6], [5, 6], [5, 1], [4, 5], [1, 4], [1, 5], [2, 0], [2, 6], [4, 6],
             [1, 0], [5, 7], [1, 6], [6, 1], [7, 6], [2, 5], [7, 1], [5, 4], [7, 0], [7, 5], [7, 2]]
        if pl in l:
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 0

        # condition for [o][s]
        l = [[2, 2], [2, 1]]
        if pl in l:
            if (self.pts[5][0] < self.pts[4][0]):
                ch1 = 0
                print("++++++++++++++++++")
                # print("00000")

        # condition for [c0][aemnst]
        l = [[0, 0], [0, 6], [0, 2], [0, 5], [0, 1], [0, 7], [5, 2], [7, 6], [7, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[4][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][
                0] and self.pts[0][0] > self.pts[20][0]) and self.pts[5][0] > self.pts[4][0]:
                ch1 = 2

        # condition for [c0][aemnst]
        l = [[6, 0], [6, 6], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[8], self.pts[16]) < 52:
                ch1 = 2


        # condition for [gh][bdfikruvw]
        l = [[1, 4], [1, 5], [1, 6], [1, 3], [1, 0]]
        pl = [ch1, ch2]

        if pl in l:
            if self.pts[6][1] > self.pts[8][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][1] and self.pts[0][0] < self.pts[8][
                0] and self.pts[0][0] < self.pts[12][0] and self.pts[0][0] < self.pts[16][0] and self.pts[0][0] < self.pts[20][0]:
                ch1 = 3



        # con for [gh][l]
        l = [[4, 6], [4, 1], [4, 5], [4, 3], [4, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][0] > self.pts[0][0]:
                ch1 = 3

        # con for [gh][pqz]
        l = [[5, 3], [5, 0], [5, 7], [5, 4], [5, 2], [5, 1], [5, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[2][1] + 15 < self.pts[16][1]:
                ch1 = 3

        # con for [l][x]
        l = [[6, 4], [6, 1], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[4], self.pts[11]) > 55:
                ch1 = 4

        # con for [l][d]
        l = [[1, 4], [1, 6], [1, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.distance(self.pts[4], self.pts[11]) > 50) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 4

        # con for [l][gh]
        l = [[3, 6], [3, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[4][0] < self.pts[0][0]):
                ch1 = 4

        # con for [l][c0]
        l = [[2, 2], [2, 5], [2, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[1][0] < self.pts[12][0]):
                ch1 = 4

        # con for [l][c0]
        l = [[2, 2], [2, 5], [2, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[1][0] < self.pts[12][0]):
                ch1 = 4

        # con for [gh][z]
        l = [[3, 6], [3, 5], [3, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]) and self.pts[4][1] > self.pts[10][1]:
                ch1 = 5

        # con for [gh][pq]
        l = [[3, 2], [3, 1], [3, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][1] + 17 > self.pts[8][1] and self.pts[4][1] + 17 > self.pts[12][1] and self.pts[4][1] + 17 > self.pts[16][1] and self.pts[4][
                1] + 17 > self.pts[20][1]:
                ch1 = 5

        # con for [l][pqz]
        l = [[4, 4], [4, 5], [4, 2], [7, 5], [7, 6], [7, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][0] > self.pts[0][0]:
                ch1 = 5

        # con for [pqz][aemnst]
        l = [[0, 2], [0, 6], [0, 1], [0, 5], [0, 0], [0, 7], [0, 4], [0, 3], [2, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[0][0] < self.pts[8][0] and self.pts[0][0] < self.pts[12][0] and self.pts[0][0] < self.pts[16][0] and self.pts[0][0] < self.pts[20][0]:
                ch1 = 5

        # con for [pqz][yj]
        l = [[5, 7], [5, 2], [5, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[3][0] < self.pts[0][0]:
                ch1 = 7

        # con for [l][yj]
        l = [[4, 6], [4, 2], [4, 4], [4, 1], [4, 5], [4, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[6][1] < self.pts[8][1]:
                ch1 = 7

        # con for [x][yj]
        l = [[6, 7], [0, 7], [0, 1], [0, 0], [6, 4], [6, 6], [6, 5], [6, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[18][1] > self.pts[20][1]:
                ch1 = 7

        # condition for [x][aemnst]
        l = [[0, 4], [0, 2], [0, 3], [0, 1], [0, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] > self.pts[16][0]:
                ch1 = 6


        # condition for [yj][x]
        print("2222  ch1=+++++++++++++++++", ch1, ",", ch2)
        l = [[7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[18][1] < self.pts[20][1] and self.pts[8][1] < self.pts[10][1]:
                ch1 = 6

        # condition for [c0][x]
        l = [[2, 1], [2, 2], [2, 6], [2, 7], [2, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[8], self.pts[16]) > 50:
                ch1 = 6

        # con for [l][x]

        l = [[4, 6], [4, 2], [4, 1], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[4], self.pts[11]) < 60:
                ch1 = 6

        # con for [x][d]
        l = [[1, 4], [1, 6], [1, 0], [1, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] - self.pts[4][0] - 15 > 0:
                ch1 = 6

        # con for [b][pqz]
        l = [[5, 0], [5, 1], [5, 4], [5, 5], [5, 6], [6, 1], [7, 6], [0, 2], [7, 1], [7, 4], [6, 6], [7, 2], [5, 0],
             [6, 3], [6, 4], [7, 5], [7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 1

        # con for [f][pqz]
        l = [[6, 1], [6, 0], [0, 3], [6, 4], [2, 2], [0, 6], [6, 2], [7, 6], [4, 6], [4, 1], [4, 2], [0, 2], [7, 1],
             [7, 4], [6, 6], [7, 2], [7, 5], [7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and
                    self.pts[18][1] > self.pts[20][1]):
                ch1 = 1

        l = [[6, 1], [6, 0], [4, 2], [4, 1], [4, 6], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and
                    self.pts[18][1] > self.pts[20][1]):
                ch1 = 1

        # con for [d][pqz]
        fg = 19
        # print("_________________ch1=",ch1," ch2=",ch2)
        l = [[5, 0], [3, 4], [3, 0], [3, 1], [3, 5], [5, 5], [5, 4], [5, 1], [7, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1]) and (self.pts[2][0] < self.pts[0][0]) and self.pts[4][1] > self.pts[14][1]):
                ch1 = 1

        l = [[4, 1], [4, 2], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.distance(self.pts[4], self.pts[11]) < 50) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 1

        l = [[3, 4], [3, 0], [3, 1], [3, 5], [3, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1]) and (self.pts[2][0] < self.pts[0][0]) and self.pts[14][1] < self.pts[4][1]):
                ch1 = 1

        l = [[6, 6], [6, 4], [6, 1], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] - self.pts[4][0] - 15 < 0:
                ch1 = 1

        # con for [i][pqz]
        l = [[5, 4], [5, 5], [5, 1], [0, 3], [0, 7], [5, 0], [0, 2], [6, 2], [7, 5], [7, 1], [7, 6], [7, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] > self.pts[20][1])):
                ch1 = 1

        # con for [yj][bfdi]
        l = [[1, 5], [1, 7], [1, 1], [1, 6], [1, 3], [1, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[4][0] < self.pts[5][0] + 15) and (
            (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
             self.pts[18][1] > self.pts[20][1])):
                ch1 = 7

        # con for [uvr]
        l = [[5, 5], [5, 0], [5, 4], [5, 1], [4, 6], [4, 1], [7, 6], [3, 0], [3, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1])) and self.pts[4][1] > self.pts[14][1]:
                ch1 = 1

        # con for [w]
        fg = 13
        l = [[3, 5], [3, 0], [3, 6], [5, 1], [4, 1], [2, 0], [5, 0], [5, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if not (self.pts[0][0] + fg < self.pts[8][0] and self.pts[0][0] + fg < self.pts[12][0] and self.pts[0][0] + fg < self.pts[16][0] and
                    self.pts[0][0] + fg < self.pts[20][0]) and not (
                    self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][0] and self.pts[0][0] > self.pts[20][
                0]) and self.distance(self.pts[4], self.pts[11]) < 50:
                ch1 = 1

        # con for [w]

        l = [[5, 0], [5, 5], [0, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1]:
                ch1 = 1

        # -------------------------condn for 8 groups  ends

        # -------------------------condn for subgroups  starts
        #
        if ch1 == 0:
            ch1 = 'S'
            if self.pts[4][0] < self.pts[6][0] and self.pts[4][0] < self.pts[10][0] and self.pts[4][0] < self.pts[14][0] and self.pts[4][0] < self.pts[18][0]:
                ch1 = 'A'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] < self.pts[10][0] and self.pts[4][0] < self.pts[14][0] and self.pts[4][0] < self.pts[18][
                0] and self.pts[4][1] < self.pts[14][1] and self.pts[4][1] < self.pts[18][1]:
                ch1 = 'T'
            if self.pts[4][1] > self.pts[8][1] and self.pts[4][1] > self.pts[12][1] and self.pts[4][1] > self.pts[16][1] and self.pts[4][1] > self.pts[20][1]:
                ch1 = 'E'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] > self.pts[10][0] and self.pts[4][0] > self.pts[14][0] and self.pts[4][1] < self.pts[18][1]:
                ch1 = 'M'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] > self.pts[10][0] and self.pts[4][1] < self.pts[18][1] and self.pts[4][1] < self.pts[14][1]:
                ch1 = 'N'

        if ch1 == 2:
            if self.distance(self.pts[12], self.pts[4]) > 42:
                ch1 = 'C'
            else:
                ch1 = 'O'

        if ch1 == 3:
            if (self.distance(self.pts[8], self.pts[12])) > 72:
                ch1 = 'G'
            else:
                ch1 = 'H'

        if ch1 == 7:
            if self.distance(self.pts[8], self.pts[4]) > 42:
                ch1 = 'Y'
            else:
                ch1 = 'J'

        if ch1 == 4:
            ch1 = 'L'

        if ch1 == 6:
            ch1 = 'X'

        if ch1 == 5:
            if self.pts[4][0] > self.pts[12][0] and self.pts[4][0] > self.pts[16][0] and self.pts[4][0] > self.pts[20][0]:
                if self.pts[8][1] < self.pts[5][1]:
                    ch1 = 'Z'
                else:
                    ch1 = 'Q'
            else:
                ch1 = 'P'

        if ch1 == 1:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'B'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 'D'
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'F'
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'I'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 'W'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]) and self.pts[4][1] < self.pts[9][1]:
                ch1 = 'K'
            if ((self.distance(self.pts[8], self.pts[12]) - self.distance(self.pts[6], self.pts[10])) < 8) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 'U'
            if ((self.distance(self.pts[8], self.pts[12]) - self.distance(self.pts[6], self.pts[10])) >= 8) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]) and (self.pts[4][1] > self.pts[9][1]):
                ch1 = 'V'

            if (self.pts[8][0] > self.pts[12][0]) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 'R'

        if ch1 == 1 or ch1 =='E' or ch1 =='S' or ch1 =='X' or ch1 =='Y' or ch1 =='B':
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] > self.pts[20][1]):
                ch1=" "



        print(self.pts[4][0] < self.pts[5][0])
        if ch1 == 'E' or ch1=='Y' or ch1=='B':
            if (self.pts[4][0] < self.pts[5][0]) and (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][1]):
                ch1="next"


        if ch1 == 'Next' or 'B' or 'C' or 'H' or 'F' or 'X':
            if (self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][0] and self.pts[0][0] > self.pts[20][0]) and (self.pts[4][1] < self.pts[8][1] and self.pts[4][1] < self.pts[12][1] and self.pts[4][1] < self.pts[16][1] and self.pts[4][1] < self.pts[20][1]) and (self.pts[4][1] < self.pts[6][1] and self.pts[4][1] < self.pts[10][1] and self.pts[4][1] < self.pts[14][1] and self.pts[4][1] < self.pts[18][1]):
                ch1 = 'Backspace'


        if ch1=="next" and self.prev_char!="next":
            if self.ten_prev_char[(self.count-2)%10]!="next":
                if self.ten_prev_char[(self.count-2)%10]=="Backspace":
                    self.str=self.str[0:-1]
                else:
                    if self.ten_prev_char[(self.count - 2) % 10] != "Backspace":
                        self.str = self.str + self.ten_prev_char[(self.count-2)%10]
            else:
                if self.ten_prev_char[(self.count - 0) % 10] != "Backspace":
                    self.str = self.str + self.ten_prev_char[(self.count - 0) % 10]


        if ch1=="  " and self.prev_char!="  ":
            self.str = self.str + "  "

        self.prev_char=ch1
        self.current_symbol=ch1
        self.count += 1
        self.ten_prev_char[self.count%10]=ch1


        if len(self.str.strip())!=0:
            st=self.str.rfind(" ")
            ed=len(self.str)
            word=self.str[st+1:ed]
            self.word=word
            if len(word.strip())!=0:
                ddd.check(word)
                lenn = len(ddd.suggest(word))
                if lenn >= 4:
                    self.word4 = ddd.suggest(word)[3]

                if lenn >= 3:
                    self.word3 = ddd.suggest(word)[2]

                if lenn >= 2:
                    self.word2 = ddd.suggest(word)[1]

                if lenn >= 1:
                    self.word1 = ddd.suggest(word)[0]
            else:
                self.word1 = " "
                self.word2 = " "
                self.word3 = " "
                self.word4 = " "


    def destructor(self):
        print(self.ten_prev_char)
        self.root.destroy()
        self.vs.release()
        cv2.destroyAllWindows()


print("Starting Application...")

(Application()).root.mainloop()

# %%
# !pip install mtranslate
# Out:
# Collecting mtranslate
#   Downloading mtranslate-1.8.tar.gz (2.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mtranslate
#   Building wheel for mtranslate (setup.py): started
#   Building wheel for mtranslate (setup.py): finished with status 'done'
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3712 sha256=1167913fe9b7acd61502f4885dc03d5a75c0764faf78982efb138288a7575d83
#   Stored in directory: c:\users\sarve\appdata\local\pip\cache\wheels\a2\20\13\93c62f314d4a29db25b1b24b2c38f79eb1beb558c727b894a3
# Successfully built mtranslate
# Installing collected packages: mtranslate
# Successfully installed mtranslate-1.8

# %%
# Importing Libraries
import numpy as np
import math
import cv2

import os, sys
import traceback
import pyttsx3
from keras.models import load_model
from cvzone.HandTrackingModule import HandDetector
from string import ascii_uppercase
import enchant
ddd=enchant.Dict("en-US")
hd = HandDetector(maxHands=1)
hd2 = HandDetector(maxHands=1)
import tkinter as tk
from PIL import Image, ImageTk
from googletrans import Translator


offset=29



class Application:

    def __init__(self):
        self.vs = cv2.VideoCapture(0)
        self.current_image = None
        self.model = load_model("D:\SEM8\Sign Language Project\Sign-Language-To-Text-and-Speech-Conversion-master\cnn8grps_rad1_model.h5")
        self.speak_engine=pyttsx3.init()
        self.speak_engine.setProperty("rate",100)
        voices=self.speak_engine.getProperty("voices")
        self.speak_engine.setProperty("voice",voices[0].id)


        self.ct = {}
        self.ct['blank'] = 0
        self.blank_flag = 0
        self.space_flag=False
        self.next_flag=True
        self.prev_char=""
        self.count=-1
        self.ten_prev_char=[]
        for i in range(10):
            self.ten_prev_char.append(" ")


        for i in ascii_uppercase:
            self.ct[i] = 0
        print("Loaded model from disk")


        self.root = tk.Tk()
        self.root.title("Sign Language To Text Conversion")
        self.root.protocol('WM_DELETE_WINDOW', self.destructor)
        self.root.geometry("1300x700")

        self.panel = tk.Label(self.root)
        self.panel.place(x=100, y=3, width=480, height=640)

        self.panel2 = tk.Label(self.root)  # initialize image panel
        self.panel2.place(x=700, y=115, width=400, height=400)

        self.T = tk.Label(self.root)
        self.T.place(x=60, y=5)
        self.T.config(text="Sign Language To Text Conversion", font=("Courier", 30, "bold"))

        self.panel3 = tk.Label(self.root)  # Current Symbol
        self.panel3.place(x=280, y=585)

        self.T1 = tk.Label(self.root)
        self.T1.place(x=10, y=580)
        self.T1.config(text="Character :", font=("Courier", 30, "bold"))

        self.panel5 = tk.Label(self.root)  # Sentence
        self.panel5.place(x=260, y=632)

        self.T3 = tk.Label(self.root)
        self.T3.place(x=10, y=632)
        self.T3.config(text="Sentence :", font=("Courier", 30, "bold"))

        self.T4 = tk.Label(self.root)
        self.T4.place(x=10, y=700)
        self.T4.config(text="Suggestions :", fg="red", font=("Courier", 30, "bold"))


        self.b1=tk.Button(self.root)
        self.b1.place(x=390,y=700)

        self.b2 = tk.Button(self.root)
        self.b2.place(x=590, y=700)

        self.b3 = tk.Button(self.root)
        self.b3.place(x=790, y=700)

        self.b4 = tk.Button(self.root)
        self.b4.place(x=990, y=700)

        self.speak = tk.Button(self.root)
        self.speak.place(x=1105, y=630)
        self.speak.config(text="Speak", font=("Courier", 20), wraplength=100, command=self.speak_fun)

        self.clear = tk.Button(self.root)
        self.clear.place(x=1005, y=630)
        self.clear.config(text="Clear", font=("Courier", 20), wraplength=100, command=self.clear_fun)

                # Dictionary of supported languages (key: language name, value: language code)
        self.languages = {
            "English": "en",
            "Tamil": "ta",
            "Hindi": "hi",
            "French": "fr",
            "Spanish": "es",
            "German": "de",
            "Chinese": "zh-cn",
            "Japanese": "ja",
            "Arabic": "ar",
            "Russian": "ru"
        }
        
        # Default selected language
        self.selected_language = tk.StringVar()
        self.selected_language.set("English")  # Default selection
        
        # Language selection dropdown
        self.language_menu = tk.OptionMenu(self.root, self.selected_language, *self.languages.keys())
        self.language_menu.config(font=("Courier", 15))
        self.language_menu.place(x=1405, y=630)  # Adjust position as needed

        self.translate_button = tk.Button(self.root, text="Translate", font=("Courier", 20), wraplength=150, command=self.translate_to_selected_language)
        self.translate_button.place(x=1205, y=630)  # Adjusted position
        

        self.str = " "
        self.ccc=0
        self.word = " "
        self.current_symbol = "C"
        self.photo = "Empty"


        self.word1=" "
        self.word2 = " "
        self.word3 = " "
        self.word4 = " "

        self.video_loop()

    def translate_to_selected_language(self):
        from mtranslate import translate
    
        selected_lang = self.selected_language.get()  # Get selected language name
        lang_code = self.languages[selected_lang]  # Get language code
    
        print(f"Translating to: {selected_lang} ({lang_code})")  # Debug info
    
        try:
            # Detect if text is already translated (assume it's not in English)
            if self.selected_language.get() == "English":
                source_lang = "auto"  # Auto-detect language and translate back to English
            else:
                source_lang = "en" if self.str.isascii() else "auto"  # If it's English, set source as 'en'
    
            # Translate using the detected source language
            translated_text = translate(self.str, lang_code, source_lang)
    
            print(f"Original: {self.str} (Source: {source_lang})")  # Debugging
            print(f"Translated: {translated_text}")  # Debugging
    
            self.str = translated_text  # Replace the displayed sentence with the translated text
            self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
    
        except Exception as e:
            print("Translation Error:", str(e))
            self.panel5.config(text="Translation Failed", font=("Courier", 30), wraplength=1025)









    def video_loop(self):
        try:
            ok, frame = self.vs.read()
            cv2image = cv2.flip(frame, 1)
            if cv2image.any:
                hands = hd.findHands(cv2image, draw=False, flipType=True)
                cv2image_copy=np.array(cv2image)
                cv2image = cv2.cvtColor(cv2image, cv2.COLOR_BGR2RGB)
                self.current_image = Image.fromarray(cv2image)
                imgtk = ImageTk.PhotoImage(image=self.current_image)
                self.panel.imgtk = imgtk
                self.panel.config(image=imgtk)

                if hands[0]:
                    hand = hands[0]
                    map = hand[0]
                    x, y, w, h=map['bbox'] 
                    image = cv2image_copy[y - offset:y + h + offset, x - offset:x + w + offset]

                    white = cv2.imread("D:\SEM8\Sign Language Project\Sign-Language-To-Text-and-Speech-Conversion-master\white.jpg")
                    # img_final=img_final1=img_final2=0
                    if image.all:
                        handz = hd2.findHands(image, draw=False, flipType=True)
                        self.ccc += 1
                        if handz[0]:
                            hand = handz[0]
                            handmap=hand[0]
                            self.pts = handmap['lmList']
                            # x1,y1,w1,h1=hand['bbox']

                            os = ((400 - w) // 2) - 15
                            os1 = ((400 - h) // 2) - 15
                            for t in range(0, 4, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(5, 8, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(9, 12, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(13, 16, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(17, 20, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            cv2.line(white, (self.pts[5][0] + os, self.pts[5][1] + os1), (self.pts[9][0] + os, self.pts[9][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[9][0] + os, self.pts[9][1] + os1), (self.pts[13][0] + os, self.pts[13][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[13][0] + os, self.pts[13][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1),
                                     (0, 255, 0), 3)
                            cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[5][0] + os, self.pts[5][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1), (0, 255, 0),
                                     3)

                            for i in range(21):
                                cv2.circle(white, (self.pts[i][0] + os, self.pts[i][1] + os1), 2, (0, 0, 255), 1)

                            res=white
                            self.predict(res)

                            self.current_image2 = Image.fromarray(res)

                            imgtk = ImageTk.PhotoImage(image=self.current_image2)

                            self.panel2.imgtk = imgtk
                            self.panel2.config(image=imgtk)

                            self.panel3.config(text=self.current_symbol, font=("Courier", 30))

                            #self.panel4.config(text=self.word, font=("Courier", 30))



                            self.b1.config(text=self.word1, font=("Courier", 20), wraplength=825, command=self.action1)
                            self.b2.config(text=self.word2, font=("Courier", 20), wraplength=825,  command=self.action2)
                            self.b3.config(text=self.word3, font=("Courier", 20), wraplength=825,  command=self.action3)
                            self.b4.config(text=self.word4, font=("Courier", 20), wraplength=825,  command=self.action4)

                self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
        except Exception:
            print(Exception.__traceback__)
            hands = hd.findHands(cv2image, draw=False, flipType=True)
            cv2image_copy=np.array(cv2image)
            cv2image = cv2.cvtColor(cv2image, cv2.COLOR_BGR2RGB)
            self.current_image = Image.fromarray(cv2image)
            imgtk = ImageTk.PhotoImage(image=self.current_image)
            self.panel.imgtk = imgtk
            self.panel.config(image=imgtk)

            if hands:
                # #print(" --------- lmlist=",hands[1])
                hand = hands[0]
                x, y, w, h = hand['bbox']
                image = cv2image_copy[y - offset:y + h + offset, x - offset:x + w + offset]

                white = cv2.imread("D:\SEM8\Sign Language Project\Sign-Language-To-Text-and-Speech-Conversion-master\white.jpg")
                # img_final=img_final1=img_final2=0

                handz = hd2.findHands(image, draw=False, flipType=True)
                print(" ", self.ccc)
                self.ccc += 1
                if handz:
                    hand = handz[0]
                    self.pts = hand['lmList']
                    # x1,y1,w1,h1=hand['bbox']

                    os = ((400 - w) // 2) - 15
                    os1 = ((400 - h) // 2) - 15
                    for t in range(0, 4, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(5, 8, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(9, 12, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(13, 16, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(17, 20, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    cv2.line(white, (self.pts[5][0] + os, self.pts[5][1] + os1), (self.pts[9][0] + os, self.pts[9][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[9][0] + os, self.pts[9][1] + os1), (self.pts[13][0] + os, self.pts[13][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[13][0] + os, self.pts[13][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1),
                             (0, 255, 0), 3)
                    cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[5][0] + os, self.pts[5][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1), (0, 255, 0),
                             3)

                    for i in range(21):
                        cv2.circle(white, (self.pts[i][0] + os, self.pts[i][1] + os1), 2, (0, 0, 255), 1)

                    res=white
                    self.predict(res)

                    self.current_image2 = Image.fromarray(res)

                    imgtk = ImageTk.PhotoImage(image=self.current_image2)

                    self.panel2.imgtk = imgtk
                    self.panel2.config(image=imgtk)

                    self.panel3.config(text=self.current_symbol, font=("Courier", 30))

                    #self.panel4.config(text=self.word, font=("Courier", 30))



                    self.b1.config(text=self.word1, font=("Courier", 20), wraplength=825, command=self.action1)
                    self.b2.config(text=self.word2, font=("Courier", 20), wraplength=825,  command=self.action2)
                    self.b3.config(text=self.word3, font=("Courier", 20), wraplength=825,  command=self.action3)
                    self.b4.config(text=self.word4, font=("Courier", 20), wraplength=825,  command=self.action4)

            self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
        except Exception:
            print("==", traceback.format_exc())
        finally:
            self.root.after(1, self.video_loop)

    def distance(self,x,y):
        return math.sqrt(((x[0] - y[0]) ** 2) + ((x[1] - y[1]) ** 2))

    def action1(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word1.upper()


    def action2(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str=self.str[:idx_word]
        self.str=self.str+self.word2.upper()
        #self.str[idx_word:last_idx] = self.word2


    def action3(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word3.upper()



    def action4(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word4.upper()


    def speak_fun(self):
        import pyttsx3
        from googletrans import Translator
    
        # Initialize text-to-speech engine
        self.speak_engine = pyttsx3.init()
        self.speak_engine.setProperty("rate", 100)
    
        # Get selected language
        lang = self.selected_language.get()
    
        # Set voice property for certain languages (TTS only supports some)
        voices = self.speak_engine.getProperty("voices")
        
        # If Tamil is selected, change voice if needed
        if lang == "Tamil":
            self.speak_engine.setProperty("voice", voices[1].id)  # Change voice if needed
        
        # Speak the translated text
        self.speak_engine.say(self.str)
        self.speak_engine.runAndWait()



    def clear_fun(self):
        self.str=" "
        self.word1 = " "
        self.word2 = " "
        self.word3 = " "
        self.word4 = " "

    def predict(self, test_image):
        white=test_image
        white = white.reshape(1, 400, 400, 3)
        prob = np.array(self.model.predict(white)[0], dtype='float32')
        ch1 = np.argmax(prob, axis=0)
        prob[ch1] = 0
        ch2 = np.argmax(prob, axis=0)
        prob[ch2] = 0
        ch3 = np.argmax(prob, axis=0)
        prob[ch3] = 0

        pl = [ch1, ch2]

        # condition for [Aemnst]
        l = [[5, 2], [5, 3], [3, 5], [3, 6], [3, 0], [3, 2], [6, 4], [6, 1], [6, 2], [6, 6], [6, 7], [6, 0], [6, 5],
             [4, 1], [1, 0], [1, 1], [6, 3], [1, 6], [5, 6], [5, 1], [4, 5], [1, 4], [1, 5], [2, 0], [2, 6], [4, 6],
             [1, 0], [5, 7], [1, 6], [6, 1], [7, 6], [2, 5], [7, 1], [5, 4], [7, 0], [7, 5], [7, 2]]
        if pl in l:
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 0

        # condition for [o][s]
        l = [[2, 2], [2, 1]]
        if pl in l:
            if (self.pts[5][0] < self.pts[4][0]):
                ch1 = 0
                print("++++++++++++++++++")
                # print("00000")

        # condition for [c0][aemnst]
        l = [[0, 0], [0, 6], [0, 2], [0, 5], [0, 1], [0, 7], [5, 2], [7, 6], [7, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[4][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][
                0] and self.pts[0][0] > self.pts[20][0]) and self.pts[5][0] > self.pts[4][0]:
                ch1 = 2

        # condition for [c0][aemnst]
        l = [[6, 0], [6, 6], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[8], self.pts[16]) < 52:
                ch1 = 2


        # condition for [gh][bdfikruvw]
        l = [[1, 4], [1, 5], [1, 6], [1, 3], [1, 0]]
        pl = [ch1, ch2]

        if pl in l:
            if self.pts[6][1] > self.pts[8][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][1] and self.pts[0][0] < self.pts[8][
                0] and self.pts[0][0] < self.pts[12][0] and self.pts[0][0] < self.pts[16][0] and self.pts[0][0] < self.pts[20][0]:
                ch1 = 3



        # con for [gh][l]
        l = [[4, 6], [4, 1], [4, 5], [4, 3], [4, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][0] > self.pts[0][0]:
                ch1 = 3

        # con for [gh][pqz]
        l = [[5, 3], [5, 0], [5, 7], [5, 4], [5, 2], [5, 1], [5, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[2][1] + 15 < self.pts[16][1]:
                ch1 = 3

        # con for [l][x]
        l = [[6, 4], [6, 1], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[4], self.pts[11]) > 55:
                ch1 = 4

        # con for [l][d]
        l = [[1, 4], [1, 6], [1, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.distance(self.pts[4], self.pts[11]) > 50) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 4

        # con for [l][gh]
        l = [[3, 6], [3, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[4][0] < self.pts[0][0]):
                ch1 = 4

        # con for [l][c0]
        l = [[2, 2], [2, 5], [2, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[1][0] < self.pts[12][0]):
                ch1 = 4

        # con for [l][c0]
        l = [[2, 2], [2, 5], [2, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[1][0] < self.pts[12][0]):
                ch1 = 4

        # con for [gh][z]
        l = [[3, 6], [3, 5], [3, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]) and self.pts[4][1] > self.pts[10][1]:
                ch1 = 5

        # con for [gh][pq]
        l = [[3, 2], [3, 1], [3, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][1] + 17 > self.pts[8][1] and self.pts[4][1] + 17 > self.pts[12][1] and self.pts[4][1] + 17 > self.pts[16][1] and self.pts[4][
                1] + 17 > self.pts[20][1]:
                ch1 = 5

        # con for [l][pqz]
        l = [[4, 4], [4, 5], [4, 2], [7, 5], [7, 6], [7, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][0] > self.pts[0][0]:
                ch1 = 5

        # con for [pqz][aemnst]
        l = [[0, 2], [0, 6], [0, 1], [0, 5], [0, 0], [0, 7], [0, 4], [0, 3], [2, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[0][0] < self.pts[8][0] and self.pts[0][0] < self.pts[12][0] and self.pts[0][0] < self.pts[16][0] and self.pts[0][0] < self.pts[20][0]:
                ch1 = 5

        # con for [pqz][yj]
        l = [[5, 7], [5, 2], [5, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[3][0] < self.pts[0][0]:
                ch1 = 7

        # con for [l][yj]
        l = [[4, 6], [4, 2], [4, 4], [4, 1], [4, 5], [4, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[6][1] < self.pts[8][1]:
                ch1 = 7

        # con for [x][yj]
        l = [[6, 7], [0, 7], [0, 1], [0, 0], [6, 4], [6, 6], [6, 5], [6, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[18][1] > self.pts[20][1]:
                ch1 = 7

        # condition for [x][aemnst]
        l = [[0, 4], [0, 2], [0, 3], [0, 1], [0, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] > self.pts[16][0]:
                ch1 = 6


        # condition for [yj][x]
        print("2222  ch1=+++++++++++++++++", ch1, ",", ch2)
        l = [[7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[18][1] < self.pts[20][1] and self.pts[8][1] < self.pts[10][1]:
                ch1 = 6

        # condition for [c0][x]
        l = [[2, 1], [2, 2], [2, 6], [2, 7], [2, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[8], self.pts[16]) > 50:
                ch1 = 6

        # con for [l][x]

        l = [[4, 6], [4, 2], [4, 1], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[4], self.pts[11]) < 60:
                ch1 = 6

        # con for [x][d]
        l = [[1, 4], [1, 6], [1, 0], [1, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] - self.pts[4][0] - 15 > 0:
                ch1 = 6

        # con for [b][pqz]
        l = [[5, 0], [5, 1], [5, 4], [5, 5], [5, 6], [6, 1], [7, 6], [0, 2], [7, 1], [7, 4], [6, 6], [7, 2], [5, 0],
             [6, 3], [6, 4], [7, 5], [7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 1

        # con for [f][pqz]
        l = [[6, 1], [6, 0], [0, 3], [6, 4], [2, 2], [0, 6], [6, 2], [7, 6], [4, 6], [4, 1], [4, 2], [0, 2], [7, 1],
             [7, 4], [6, 6], [7, 2], [7, 5], [7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and
                    self.pts[18][1] > self.pts[20][1]):
                ch1 = 1

        l = [[6, 1], [6, 0], [4, 2], [4, 1], [4, 6], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and
                    self.pts[18][1] > self.pts[20][1]):
                ch1 = 1

        # con for [d][pqz]
        fg = 19
        # print("_________________ch1=",ch1," ch2=",ch2)
        l = [[5, 0], [3, 4], [3, 0], [3, 1], [3, 5], [5, 5], [5, 4], [5, 1], [7, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1]) and (self.pts[2][0] < self.pts[0][0]) and self.pts[4][1] > self.pts[14][1]):
                ch1 = 1

        l = [[4, 1], [4, 2], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.distance(self.pts[4], self.pts[11]) < 50) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 1

        l = [[3, 4], [3, 0], [3, 1], [3, 5], [3, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1]) and (self.pts[2][0] < self.pts[0][0]) and self.pts[14][1] < self.pts[4][1]):
                ch1 = 1

        l = [[6, 6], [6, 4], [6, 1], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] - self.pts[4][0] - 15 < 0:
                ch1 = 1

        # con for [i][pqz]
        l = [[5, 4], [5, 5], [5, 1], [0, 3], [0, 7], [5, 0], [0, 2], [6, 2], [7, 5], [7, 1], [7, 6], [7, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] > self.pts[20][1])):
                ch1 = 1

        # con for [yj][bfdi]
        l = [[1, 5], [1, 7], [1, 1], [1, 6], [1, 3], [1, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[4][0] < self.pts[5][0] + 15) and (
            (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
             self.pts[18][1] > self.pts[20][1])):
                ch1 = 7

        # con for [uvr]
        l = [[5, 5], [5, 0], [5, 4], [5, 1], [4, 6], [4, 1], [7, 6], [3, 0], [3, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1])) and self.pts[4][1] > self.pts[14][1]:
                ch1 = 1

        # con for [w]
        fg = 13
        l = [[3, 5], [3, 0], [3, 6], [5, 1], [4, 1], [2, 0], [5, 0], [5, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if not (self.pts[0][0] + fg < self.pts[8][0] and self.pts[0][0] + fg < self.pts[12][0] and self.pts[0][0] + fg < self.pts[16][0] and
                    self.pts[0][0] + fg < self.pts[20][0]) and not (
                    self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][0] and self.pts[0][0] > self.pts[20][
                0]) and self.distance(self.pts[4], self.pts[11]) < 50:
                ch1 = 1

        # con for [w]

        l = [[5, 0], [5, 5], [0, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1]:
                ch1 = 1

        # -------------------------condn for 8 groups  ends

        # -------------------------condn for subgroups  starts
        #
        if ch1 == 0:
            ch1 = 'S'
            if self.pts[4][0] < self.pts[6][0] and self.pts[4][0] < self.pts[10][0] and self.pts[4][0] < self.pts[14][0] and self.pts[4][0] < self.pts[18][0]:
                ch1 = 'A'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] < self.pts[10][0] and self.pts[4][0] < self.pts[14][0] and self.pts[4][0] < self.pts[18][
                0] and self.pts[4][1] < self.pts[14][1] and self.pts[4][1] < self.pts[18][1]:
                ch1 = 'T'
            if self.pts[4][1] > self.pts[8][1] and self.pts[4][1] > self.pts[12][1] and self.pts[4][1] > self.pts[16][1] and self.pts[4][1] > self.pts[20][1]:
                ch1 = 'E'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] > self.pts[10][0] and self.pts[4][0] > self.pts[14][0] and self.pts[4][1] < self.pts[18][1]:
                ch1 = 'M'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] > self.pts[10][0] and self.pts[4][1] < self.pts[18][1] and self.pts[4][1] < self.pts[14][1]:
                ch1 = 'N'

        if ch1 == 2:
            if self.distance(self.pts[12], self.pts[4]) > 42:
                ch1 = 'C'
            else:
                ch1 = 'O'

        if ch1 == 3:
            if (self.distance(self.pts[8], self.pts[12])) > 72:
                ch1 = 'G'
            else:
                ch1 = 'H'

        if ch1 == 7:
            if self.distance(self.pts[8], self.pts[4]) > 42:
                ch1 = 'Y'
            else:
                ch1 = 'J'

        if ch1 == 4:
            ch1 = 'L'

        if ch1 == 6:
            ch1 = 'X'

        if ch1 == 5:
            if self.pts[4][0] > self.pts[12][0] and self.pts[4][0] > self.pts[16][0] and self.pts[4][0] > self.pts[20][0]:
                if self.pts[8][1] < self.pts[5][1]:
                    ch1 = 'Z'
                else:
                    ch1 = 'Q'
            else:
                ch1 = 'P'

        if ch1 == 1:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'B'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 'D'
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'F'
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'I'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 'W'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]) and self.pts[4][1] < self.pts[9][1]:
                ch1 = 'K'
            if ((self.distance(self.pts[8], self.pts[12]) - self.distance(self.pts[6], self.pts[10])) < 8) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 'U'
            if ((self.distance(self.pts[8], self.pts[12]) - self.distance(self.pts[6], self.pts[10])) >= 8) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]) and (self.pts[4][1] > self.pts[9][1]):
                ch1 = 'V'

            if (self.pts[8][0] > self.pts[12][0]) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 'R'

        if ch1 == 1 or ch1 =='E' or ch1 =='S' or ch1 =='X' or ch1 =='Y' or ch1 =='B':
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] > self.pts[20][1]):
                ch1=" "



        print(self.pts[4][0] < self.pts[5][0])
        if ch1 == 'E' or ch1=='Y' or ch1=='B':
            if (self.pts[4][0] < self.pts[5][0]) and (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][1]):
                ch1="next"


        if ch1 == 'Next' or 'B' or 'C' or 'H' or 'F' or 'X':
            if (self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][0] and self.pts[0][0] > self.pts[20][0]) and (self.pts[4][1] < self.pts[8][1] and self.pts[4][1] < self.pts[12][1] and self.pts[4][1] < self.pts[16][1] and self.pts[4][1] < self.pts[20][1]) and (self.pts[4][1] < self.pts[6][1] and self.pts[4][1] < self.pts[10][1] and self.pts[4][1] < self.pts[14][1] and self.pts[4][1] < self.pts[18][1]):
                ch1 = 'Backspace'


        if ch1=="next" and self.prev_char!="next":
            if self.ten_prev_char[(self.count-2)%10]!="next":
                if self.ten_prev_char[(self.count-2)%10]=="Backspace":
                    self.str=self.str[0:-1]
                else:
                    if self.ten_prev_char[(self.count - 2) % 10] != "Backspace":
                        self.str = self.str + self.ten_prev_char[(self.count-2)%10]
            else:
                if self.ten_prev_char[(self.count - 0) % 10] != "Backspace":
                    self.str = self.str + self.ten_prev_char[(self.count - 0) % 10]


        if ch1=="  " and self.prev_char!="  ":
            self.str = self.str + "  "

        self.prev_char=ch1
        self.current_symbol=ch1
        self.count += 1
        self.ten_prev_char[self.count%10]=ch1


        if len(self.str.strip())!=0:
            st=self.str.rfind(" ")
            ed=len(self.str)
            word=self.str[st+1:ed]
            self.word=word
            if len(word.strip())!=0:
                ddd.check(word)
                lenn = len(ddd.suggest(word))
                if lenn >= 4:
                    self.word4 = ddd.suggest(word)[3]

                if lenn >= 3:
                    self.word3 = ddd.suggest(word)[2]

                if lenn >= 2:
                    self.word2 = ddd.suggest(word)[1]

                if lenn >= 1:
                    self.word1 = ddd.suggest(word)[0]
            else:
                self.word1 = " "
                self.word2 = " "
                self.word3 = " "
                self.word4 = " "


    def destructor(self):
        print(self.ten_prev_char)
        self.root.destroy()
        self.vs.release()
        cv2.destroyAllWindows()


print("Starting Application...")

(Application()).root.mainloop()
# Out:
# Starting Application...
# Loaded model from disk
# 1/1 [==============================] - 3s 3s/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# True
# 1/1 [==============================] - 0s 19ms/step
# 2222  ch1=+++++++++++++++++ 7 , 2
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 6 , 1
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 0 , 0
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# False
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 7 , 6
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# True
# 1/1 [==============================] - 0s 21ms/step
# 2222  ch1=+++++++++++++++++ 3 , 5
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 5 , 0
# False
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 21ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 21ms/step
# 2222  ch1=+++++++++++++++++ 7 , 3
# True
# 1/1 [==============================] - 0s 21ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 19ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 21ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 7 , 3
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 19ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 23ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 1 , 0
# True
# 1/1 [==============================] - 0s 21ms/step
# 2222  ch1=+++++++++++++++++ 7 , 7
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 21ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 1
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 23ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 1
# True
# 1/1 [==============================] - 0s 19ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 6ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 4ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 21ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 22ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 928us/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 5
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# Translating to: Tamil (ta)
# Original:  HELLO (Source: en)
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம் (Source: auto)
# Translated: Ni
# Translating to: Tamil (ta)
# Original: Ni (Source: en)
# Translated: நி
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# ['O', 'O', 'next', 'next', 'next', 'P', 'E', 'O', 'O', 'O']

# %%
# Importing Libraries
import numpy as np
import math
import cv2

import os, sys
import traceback
import pyttsx3
from keras.models import load_model
from cvzone.HandTrackingModule import HandDetector
from string import ascii_uppercase
import enchant
ddd=enchant.Dict("en-US")
hd = HandDetector(maxHands=1)
hd2 = HandDetector(maxHands=1)
import tkinter as tk
from PIL import Image, ImageTk
from googletrans import Translator


offset=29



class Application:

    def __init__(self):
        self.vs = cv2.VideoCapture(0)
        self.current_image = None
        self.model = load_model("D:\SEM8\Sign Language Project\Sign-Language-To-Text-and-Speech-Conversion-master\cnn8grps_rad1_model.h5")
        self.speak_engine=pyttsx3.init()
        self.speak_engine.setProperty("rate",100)
        voices=self.speak_engine.getProperty("voices")
        self.speak_engine.setProperty("voice",voices[0].id)


        self.ct = {}
        self.ct['blank'] = 0
        self.blank_flag = 0
        self.space_flag=False
        self.next_flag=True
        self.prev_char=""
        self.count=-1
        self.ten_prev_char=[]
        for i in range(10):
            self.ten_prev_char.append(" ")


        for i in ascii_uppercase:
            self.ct[i] = 0
        print("Loaded model from disk")


        self.root = tk.Tk()
        self.root.title("Sign Language To Text Conversion")
        self.root.protocol('WM_DELETE_WINDOW', self.destructor)
        self.root.geometry("1300x700")

        self.panel = tk.Label(self.root)
        self.panel.place(x=100, y=3, width=480, height=640)

        self.panel2 = tk.Label(self.root)  # initialize image panel
        self.panel2.place(x=700, y=115, width=400, height=400)

        self.T = tk.Label(self.root)
        self.T.place(x=60, y=5)
        self.T.config(text="Sign Language To Text Conversion", font=("Courier", 30, "bold"))

        self.panel3 = tk.Label(self.root)  # Current Symbol
        self.panel3.place(x=280, y=585)

        self.T1 = tk.Label(self.root)
        self.T1.place(x=10, y=580)
        self.T1.config(text="Character :", font=("Courier", 30, "bold"))

        self.panel5 = tk.Label(self.root)  # Sentence
        self.panel5.place(x=260, y=632)

        self.T3 = tk.Label(self.root)
        self.T3.place(x=10, y=632)
        self.T3.config(text="Sentence :", font=("Courier", 30, "bold"))

        self.T4 = tk.Label(self.root)
        self.T4.place(x=10, y=700)
        self.T4.config(text="Suggestions :", fg="red", font=("Courier", 30, "bold"))


        self.b1=tk.Button(self.root)
        self.b1.place(x=390,y=700)

        self.b2 = tk.Button(self.root)
        self.b2.place(x=590, y=700)

        self.b3 = tk.Button(self.root)
        self.b3.place(x=790, y=700)

        self.b4 = tk.Button(self.root)
        self.b4.place(x=990, y=700)

        self.speak = tk.Button(self.root)
        self.speak.place(x=1105, y=630)
        self.speak.config(text="Speak", font=("Courier", 20), wraplength=100, command=self.speak_fun)

        self.clear = tk.Button(self.root)
        self.clear.place(x=1005, y=630)
        self.clear.config(text="Clear", font=("Courier", 20), wraplength=100, command=self.clear_fun)

                # Dictionary of supported languages (key: language name, value: language code)
        self.languages = {
            "English": "en",
            "Tamil": "ta",
            "Hindi": "hi",
            "Telugu": "te",
            "Marathi": "mr",
            "Gujarati": "gu",
            "Bengali": "bn",
            "Kannada": "kn",
            "Malayalam": "ml",
            "Punjabi": "pa",
            "French": "fr",
            "Spanish": "es",
            "German": "de",
            "Russian": "ru",
            "Italian": "it",
            "Portuguese": "pt"
        }

        
        # Default selected language
        self.selected_language = tk.StringVar()
        self.selected_language.set("English")  # Default selection
        
        # Language selection dropdown
        self.language_menu = tk.OptionMenu(self.root, self.selected_language, *self.languages.keys())
        self.language_menu.config(font=("Courier", 15))
        self.language_menu.place(x=1405, y=630)  # Adjust position as needed

        self.translate_button = tk.Button(self.root, text="Translate", font=("Courier", 20), wraplength=150, command=self.translate_to_selected_language)
        self.translate_button.place(x=1205, y=630)  # Adjusted position


        self.str = " "
        self.ccc=0
        self.word = " "
        self.current_symbol = "C"
        self.photo = "Empty"
        self.original_text = ""  # Store original English text


        self.word1=" "
        self.word2 = " "
        self.word3 = " "
        self.word4 = " "

        self.video_loop()

    def translate_to_selected_language(self):
        from mtranslate import translate
    
        selected_lang = self.selected_language.get()  # Get selected language name
        lang_code = self.languages[selected_lang]  # Get language code
    
        print(f"Translating to: {selected_lang} ({lang_code})")  # Debug info
    
        try:
            # If English is selected, restore the original sentence
            if selected_lang == "English":
                self.str = self.original_text  # Restore original English text
            else:
                # Save original text only if translating from English
                if self.selected_language.get() == "Tamil" or self.str.isascii():
                    self.original_text = self.str  # Store the original English sentence
                
                translated_text = translate(self.str, lang_code, "auto")  # Auto-detect the source language
                self.str = translated_text  # Update translated text
    
            self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
    
            print(f"Original: {self.original_text}")
            print(f"Translated: {self.str}")
    
        except Exception as e:
            print("Translation Error:", str(e))
            self.panel5.config(text="Translation Failed", font=("Courier", 30), wraplength=1025)









    def video_loop(self):
        try:
            ok, frame = self.vs.read()
            cv2image = cv2.flip(frame, 1)
            if cv2image.any:
                hands = hd.findHands(cv2image, draw=False, flipType=True)
                cv2image_copy=np.array(cv2image)
                cv2image = cv2.cvtColor(cv2image, cv2.COLOR_BGR2RGB)
                self.current_image = Image.fromarray(cv2image)
                imgtk = ImageTk.PhotoImage(image=self.current_image)
                self.panel.imgtk = imgtk
                self.panel.config(image=imgtk)

                if hands[0]:
                    hand = hands[0]
                    map = hand[0]
                    x, y, w, h=map['bbox'] 
                    image = cv2image_copy[y - offset:y + h + offset, x - offset:x + w + offset]

                    white = cv2.imread("D:\SEM8\Sign Language Project\Sign-Language-To-Text-and-Speech-Conversion-master\white.jpg")
                    # img_final=img_final1=img_final2=0
                    if image.all:
                        handz = hd2.findHands(image, draw=False, flipType=True)
                        self.ccc += 1
                        if handz[0]:
                            hand = handz[0]
                            handmap=hand[0]
                            self.pts = handmap['lmList']
                            # x1,y1,w1,h1=hand['bbox']

                            os = ((400 - w) // 2) - 15
                            os1 = ((400 - h) // 2) - 15
                            for t in range(0, 4, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(5, 8, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(9, 12, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(13, 16, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(17, 20, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            cv2.line(white, (self.pts[5][0] + os, self.pts[5][1] + os1), (self.pts[9][0] + os, self.pts[9][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[9][0] + os, self.pts[9][1] + os1), (self.pts[13][0] + os, self.pts[13][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[13][0] + os, self.pts[13][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1),
                                     (0, 255, 0), 3)
                            cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[5][0] + os, self.pts[5][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1), (0, 255, 0),
                                     3)

                            for i in range(21):
                                cv2.circle(white, (self.pts[i][0] + os, self.pts[i][1] + os1), 2, (0, 0, 255), 1)

                            res=white
                            self.predict(res)

                            self.current_image2 = Image.fromarray(res)

                            imgtk = ImageTk.PhotoImage(image=self.current_image2)

                            self.panel2.imgtk = imgtk
                            self.panel2.config(image=imgtk)

                            self.panel3.config(text=self.current_symbol, font=("Courier", 30))

                            #self.panel4.config(text=self.word, font=("Courier", 30))



                            self.b1.config(text=self.word1, font=("Courier", 20), wraplength=825, command=self.action1)
                            self.b2.config(text=self.word2, font=("Courier", 20), wraplength=825,  command=self.action2)
                            self.b3.config(text=self.word3, font=("Courier", 20), wraplength=825,  command=self.action3)
                            self.b4.config(text=self.word4, font=("Courier", 20), wraplength=825,  command=self.action4)

                self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
        except Exception:
            print(Exception.__traceback__)
            hands = hd.findHands(cv2image, draw=False, flipType=True)
            cv2image_copy=np.array(cv2image)
            cv2image = cv2.cvtColor(cv2image, cv2.COLOR_BGR2RGB)
            self.current_image = Image.fromarray(cv2image)
            imgtk = ImageTk.PhotoImage(image=self.current_image)
            self.panel.imgtk = imgtk
            self.panel.config(image=imgtk)

            if hands:
                # #print(" --------- lmlist=",hands[1])
                hand = hands[0]
                x, y, w, h = hand['bbox']
                image = cv2image_copy[y - offset:y + h + offset, x - offset:x + w + offset]

                white = cv2.imread("D:\SEM8\Sign Language Project\Sign-Language-To-Text-and-Speech-Conversion-master\white.jpg")
                # img_final=img_final1=img_final2=0

                handz = hd2.findHands(image, draw=False, flipType=True)
                print(" ", self.ccc)
                self.ccc += 1
                if handz:
                    hand = handz[0]
                    self.pts = hand['lmList']
                    # x1,y1,w1,h1=hand['bbox']

                    os = ((400 - w) // 2) - 15
                    os1 = ((400 - h) // 2) - 15
                    for t in range(0, 4, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(5, 8, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(9, 12, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(13, 16, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(17, 20, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    cv2.line(white, (self.pts[5][0] + os, self.pts[5][1] + os1), (self.pts[9][0] + os, self.pts[9][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[9][0] + os, self.pts[9][1] + os1), (self.pts[13][0] + os, self.pts[13][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[13][0] + os, self.pts[13][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1),
                             (0, 255, 0), 3)
                    cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[5][0] + os, self.pts[5][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1), (0, 255, 0),
                             3)

                    for i in range(21):
                        cv2.circle(white, (self.pts[i][0] + os, self.pts[i][1] + os1), 2, (0, 0, 255), 1)

                    res=white
                    self.predict(res)

                    self.current_image2 = Image.fromarray(res)

                    imgtk = ImageTk.PhotoImage(image=self.current_image2)

                    self.panel2.imgtk = imgtk
                    self.panel2.config(image=imgtk)

                    self.panel3.config(text=self.current_symbol, font=("Courier", 30))

                    #self.panel4.config(text=self.word, font=("Courier", 30))



                    self.b1.config(text=self.word1, font=("Courier", 20), wraplength=825, command=self.action1)
                    self.b2.config(text=self.word2, font=("Courier", 20), wraplength=825,  command=self.action2)
                    self.b3.config(text=self.word3, font=("Courier", 20), wraplength=825,  command=self.action3)
                    self.b4.config(text=self.word4, font=("Courier", 20), wraplength=825,  command=self.action4)

            self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
        except Exception:
            print("==", traceback.format_exc())
        finally:
            self.root.after(1, self.video_loop)

    def distance(self,x,y):
        return math.sqrt(((x[0] - y[0]) ** 2) + ((x[1] - y[1]) ** 2))

    def action1(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word1.upper()


    def action2(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str=self.str[:idx_word]
        self.str=self.str+self.word2.upper()
        #self.str[idx_word:last_idx] = self.word2


    def action3(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word3.upper()



    def action4(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word4.upper()


    def speak_fun(self):
        import pyttsx3
        from googletrans import Translator
    
        # Initialize text-to-speech engine
        self.speak_engine = pyttsx3.init()
        self.speak_engine.setProperty("rate", 100)
    
        # Get selected language
        lang = self.selected_language.get()
    
        # Set voice property for certain languages (TTS only supports some)
        voices = self.speak_engine.getProperty("voices")
        
        # If Tamil is selected, change voice if needed
        if lang == "Tamil":
            self.speak_engine.setProperty("voice", voices[1].id)  # Change voice if needed
        
        # Speak the translated text
        self.speak_engine.say(self.str)
        self.speak_engine.runAndWait()



    def clear_fun(self):
        self.str=" "
        self.word1 = " "
        self.word2 = " "
        self.word3 = " "
        self.word4 = " "

    def predict(self, test_image):
        white=test_image
        white = white.reshape(1, 400, 400, 3)
        prob = np.array(self.model.predict(white)[0], dtype='float32')
        ch1 = np.argmax(prob, axis=0)
        prob[ch1] = 0
        ch2 = np.argmax(prob, axis=0)
        prob[ch2] = 0
        ch3 = np.argmax(prob, axis=0)
        prob[ch3] = 0

        pl = [ch1, ch2]

        # condition for [Aemnst]
        l = [[5, 2], [5, 3], [3, 5], [3, 6], [3, 0], [3, 2], [6, 4], [6, 1], [6, 2], [6, 6], [6, 7], [6, 0], [6, 5],
             [4, 1], [1, 0], [1, 1], [6, 3], [1, 6], [5, 6], [5, 1], [4, 5], [1, 4], [1, 5], [2, 0], [2, 6], [4, 6],
             [1, 0], [5, 7], [1, 6], [6, 1], [7, 6], [2, 5], [7, 1], [5, 4], [7, 0], [7, 5], [7, 2]]
        if pl in l:
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 0

        # condition for [o][s]
        l = [[2, 2], [2, 1]]
        if pl in l:
            if (self.pts[5][0] < self.pts[4][0]):
                ch1 = 0
                print("++++++++++++++++++")
                # print("00000")

        # condition for [c0][aemnst]
        l = [[0, 0], [0, 6], [0, 2], [0, 5], [0, 1], [0, 7], [5, 2], [7, 6], [7, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[4][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][
                0] and self.pts[0][0] > self.pts[20][0]) and self.pts[5][0] > self.pts[4][0]:
                ch1 = 2

        # condition for [c0][aemnst]
        l = [[6, 0], [6, 6], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[8], self.pts[16]) < 52:
                ch1 = 2


        # condition for [gh][bdfikruvw]
        l = [[1, 4], [1, 5], [1, 6], [1, 3], [1, 0]]
        pl = [ch1, ch2]

        if pl in l:
            if self.pts[6][1] > self.pts[8][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][1] and self.pts[0][0] < self.pts[8][
                0] and self.pts[0][0] < self.pts[12][0] and self.pts[0][0] < self.pts[16][0] and self.pts[0][0] < self.pts[20][0]:
                ch1 = 3



        # con for [gh][l]
        l = [[4, 6], [4, 1], [4, 5], [4, 3], [4, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][0] > self.pts[0][0]:
                ch1 = 3

        # con for [gh][pqz]
        l = [[5, 3], [5, 0], [5, 7], [5, 4], [5, 2], [5, 1], [5, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[2][1] + 15 < self.pts[16][1]:
                ch1 = 3

        # con for [l][x]
        l = [[6, 4], [6, 1], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[4], self.pts[11]) > 55:
                ch1 = 4

        # con for [l][d]
        l = [[1, 4], [1, 6], [1, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.distance(self.pts[4], self.pts[11]) > 50) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 4

        # con for [l][gh]
        l = [[3, 6], [3, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[4][0] < self.pts[0][0]):
                ch1 = 4

        # con for [l][c0]
        l = [[2, 2], [2, 5], [2, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[1][0] < self.pts[12][0]):
                ch1 = 4

        # con for [l][c0]
        l = [[2, 2], [2, 5], [2, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[1][0] < self.pts[12][0]):
                ch1 = 4

        # con for [gh][z]
        l = [[3, 6], [3, 5], [3, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]) and self.pts[4][1] > self.pts[10][1]:
                ch1 = 5

        # con for [gh][pq]
        l = [[3, 2], [3, 1], [3, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][1] + 17 > self.pts[8][1] and self.pts[4][1] + 17 > self.pts[12][1] and self.pts[4][1] + 17 > self.pts[16][1] and self.pts[4][
                1] + 17 > self.pts[20][1]:
                ch1 = 5

        # con for [l][pqz]
        l = [[4, 4], [4, 5], [4, 2], [7, 5], [7, 6], [7, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][0] > self.pts[0][0]:
                ch1 = 5

        # con for [pqz][aemnst]
        l = [[0, 2], [0, 6], [0, 1], [0, 5], [0, 0], [0, 7], [0, 4], [0, 3], [2, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[0][0] < self.pts[8][0] and self.pts[0][0] < self.pts[12][0] and self.pts[0][0] < self.pts[16][0] and self.pts[0][0] < self.pts[20][0]:
                ch1 = 5

        # con for [pqz][yj]
        l = [[5, 7], [5, 2], [5, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[3][0] < self.pts[0][0]:
                ch1 = 7

        # con for [l][yj]
        l = [[4, 6], [4, 2], [4, 4], [4, 1], [4, 5], [4, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[6][1] < self.pts[8][1]:
                ch1 = 7

        # con for [x][yj]
        l = [[6, 7], [0, 7], [0, 1], [0, 0], [6, 4], [6, 6], [6, 5], [6, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[18][1] > self.pts[20][1]:
                ch1 = 7

        # condition for [x][aemnst]
        l = [[0, 4], [0, 2], [0, 3], [0, 1], [0, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] > self.pts[16][0]:
                ch1 = 6


        # condition for [yj][x]
        print("2222  ch1=+++++++++++++++++", ch1, ",", ch2)
        l = [[7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[18][1] < self.pts[20][1] and self.pts[8][1] < self.pts[10][1]:
                ch1 = 6

        # condition for [c0][x]
        l = [[2, 1], [2, 2], [2, 6], [2, 7], [2, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[8], self.pts[16]) > 50:
                ch1 = 6

        # con for [l][x]

        l = [[4, 6], [4, 2], [4, 1], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[4], self.pts[11]) < 60:
                ch1 = 6

        # con for [x][d]
        l = [[1, 4], [1, 6], [1, 0], [1, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] - self.pts[4][0] - 15 > 0:
                ch1 = 6

        # con for [b][pqz]
        l = [[5, 0], [5, 1], [5, 4], [5, 5], [5, 6], [6, 1], [7, 6], [0, 2], [7, 1], [7, 4], [6, 6], [7, 2], [5, 0],
             [6, 3], [6, 4], [7, 5], [7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 1

        # con for [f][pqz]
        l = [[6, 1], [6, 0], [0, 3], [6, 4], [2, 2], [0, 6], [6, 2], [7, 6], [4, 6], [4, 1], [4, 2], [0, 2], [7, 1],
             [7, 4], [6, 6], [7, 2], [7, 5], [7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and
                    self.pts[18][1] > self.pts[20][1]):
                ch1 = 1

        l = [[6, 1], [6, 0], [4, 2], [4, 1], [4, 6], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and
                    self.pts[18][1] > self.pts[20][1]):
                ch1 = 1

        # con for [d][pqz]
        fg = 19
        # print("_________________ch1=",ch1," ch2=",ch2)
        l = [[5, 0], [3, 4], [3, 0], [3, 1], [3, 5], [5, 5], [5, 4], [5, 1], [7, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1]) and (self.pts[2][0] < self.pts[0][0]) and self.pts[4][1] > self.pts[14][1]):
                ch1 = 1

        l = [[4, 1], [4, 2], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.distance(self.pts[4], self.pts[11]) < 50) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 1

        l = [[3, 4], [3, 0], [3, 1], [3, 5], [3, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1]) and (self.pts[2][0] < self.pts[0][0]) and self.pts[14][1] < self.pts[4][1]):
                ch1 = 1

        l = [[6, 6], [6, 4], [6, 1], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] - self.pts[4][0] - 15 < 0:
                ch1 = 1

        # con for [i][pqz]
        l = [[5, 4], [5, 5], [5, 1], [0, 3], [0, 7], [5, 0], [0, 2], [6, 2], [7, 5], [7, 1], [7, 6], [7, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] > self.pts[20][1])):
                ch1 = 1

        # con for [yj][bfdi]
        l = [[1, 5], [1, 7], [1, 1], [1, 6], [1, 3], [1, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[4][0] < self.pts[5][0] + 15) and (
            (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
             self.pts[18][1] > self.pts[20][1])):
                ch1 = 7

        # con for [uvr]
        l = [[5, 5], [5, 0], [5, 4], [5, 1], [4, 6], [4, 1], [7, 6], [3, 0], [3, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1])) and self.pts[4][1] > self.pts[14][1]:
                ch1 = 1

        # con for [w]
        fg = 13
        l = [[3, 5], [3, 0], [3, 6], [5, 1], [4, 1], [2, 0], [5, 0], [5, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if not (self.pts[0][0] + fg < self.pts[8][0] and self.pts[0][0] + fg < self.pts[12][0] and self.pts[0][0] + fg < self.pts[16][0] and
                    self.pts[0][0] + fg < self.pts[20][0]) and not (
                    self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][0] and self.pts[0][0] > self.pts[20][
                0]) and self.distance(self.pts[4], self.pts[11]) < 50:
                ch1 = 1

        # con for [w]

        l = [[5, 0], [5, 5], [0, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1]:
                ch1 = 1

        # -------------------------condn for 8 groups  ends

        # -------------------------condn for subgroups  starts
        #
        if ch1 == 0:
            ch1 = 'S'
            if self.pts[4][0] < self.pts[6][0] and self.pts[4][0] < self.pts[10][0] and self.pts[4][0] < self.pts[14][0] and self.pts[4][0] < self.pts[18][0]:
                ch1 = 'A'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] < self.pts[10][0] and self.pts[4][0] < self.pts[14][0] and self.pts[4][0] < self.pts[18][
                0] and self.pts[4][1] < self.pts[14][1] and self.pts[4][1] < self.pts[18][1]:
                ch1 = 'T'
            if self.pts[4][1] > self.pts[8][1] and self.pts[4][1] > self.pts[12][1] and self.pts[4][1] > self.pts[16][1] and self.pts[4][1] > self.pts[20][1]:
                ch1 = 'E'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] > self.pts[10][0] and self.pts[4][0] > self.pts[14][0] and self.pts[4][1] < self.pts[18][1]:
                ch1 = 'M'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] > self.pts[10][0] and self.pts[4][1] < self.pts[18][1] and self.pts[4][1] < self.pts[14][1]:
                ch1 = 'N'

        if ch1 == 2:
            if self.distance(self.pts[12], self.pts[4]) > 42:
                ch1 = 'C'
            else:
                ch1 = 'O'

        if ch1 == 3:
            if (self.distance(self.pts[8], self.pts[12])) > 72:
                ch1 = 'G'
            else:
                ch1 = 'H'

        if ch1 == 7:
            if self.distance(self.pts[8], self.pts[4]) > 42:
                ch1 = 'Y'
            else:
                ch1 = 'J'

        if ch1 == 4:
            ch1 = 'L'

        if ch1 == 6:
            ch1 = 'X'

        if ch1 == 5:
            if self.pts[4][0] > self.pts[12][0] and self.pts[4][0] > self.pts[16][0] and self.pts[4][0] > self.pts[20][0]:
                if self.pts[8][1] < self.pts[5][1]:
                    ch1 = 'Z'
                else:
                    ch1 = 'Q'
            else:
                ch1 = 'P'

        if ch1 == 1:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'B'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 'D'
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'F'
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'I'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 'W'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]) and self.pts[4][1] < self.pts[9][1]:
                ch1 = 'K'
            if ((self.distance(self.pts[8], self.pts[12]) - self.distance(self.pts[6], self.pts[10])) < 8) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 'U'
            if ((self.distance(self.pts[8], self.pts[12]) - self.distance(self.pts[6], self.pts[10])) >= 8) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]) and (self.pts[4][1] > self.pts[9][1]):
                ch1 = 'V'

            if (self.pts[8][0] > self.pts[12][0]) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 'R'

        if ch1 == 1 or ch1 =='E' or ch1 =='S' or ch1 =='X' or ch1 =='Y' or ch1 =='B':
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] > self.pts[20][1]):
                ch1=" "



        print(self.pts[4][0] < self.pts[5][0])
        if ch1 == 'E' or ch1=='Y' or ch1=='B':
            if (self.pts[4][0] < self.pts[5][0]) and (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][1]):
                ch1="next"


        if ch1 == 'Next' or 'B' or 'C' or 'H' or 'F' or 'X':
            if (self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][0] and self.pts[0][0] > self.pts[20][0]) and (self.pts[4][1] < self.pts[8][1] and self.pts[4][1] < self.pts[12][1] and self.pts[4][1] < self.pts[16][1] and self.pts[4][1] < self.pts[20][1]) and (self.pts[4][1] < self.pts[6][1] and self.pts[4][1] < self.pts[10][1] and self.pts[4][1] < self.pts[14][1] and self.pts[4][1] < self.pts[18][1]):
                ch1 = 'Backspace'


        if ch1=="next" and self.prev_char!="next":
            if self.ten_prev_char[(self.count-2)%10]!="next":
                if self.ten_prev_char[(self.count-2)%10]=="Backspace":
                    self.str=self.str[0:-1]
                else:
                    if self.ten_prev_char[(self.count - 2) % 10] != "Backspace":
                        self.str = self.str + self.ten_prev_char[(self.count-2)%10]
            else:
                if self.ten_prev_char[(self.count - 0) % 10] != "Backspace":
                    self.str = self.str + self.ten_prev_char[(self.count - 0) % 10]


        if ch1=="  " and self.prev_char!="  ":
            self.str = self.str + "  "

        self.prev_char=ch1
        self.current_symbol=ch1
        self.count += 1
        self.ten_prev_char[self.count%10]=ch1


        if len(self.str.strip())!=0:
            st=self.str.rfind(" ")
            ed=len(self.str)
            word=self.str[st+1:ed]
            self.word=word
            if len(word.strip())!=0:
                ddd.check(word)
                lenn = len(ddd.suggest(word))
                if lenn >= 4:
                    self.word4 = ddd.suggest(word)[3]

                if lenn >= 3:
                    self.word3 = ddd.suggest(word)[2]

                if lenn >= 2:
                    self.word2 = ddd.suggest(word)[1]

                if lenn >= 1:
                    self.word1 = ddd.suggest(word)[0]
            else:
                self.word1 = " "
                self.word2 = " "
                self.word3 = " "
                self.word4 = " "


    def destructor(self):
        print(self.ten_prev_char)
        self.root.destroy()
        self.vs.release()
        cv2.destroyAllWindows()


print("Starting Application...")

(Application()).root.mainloop()
# Out:
# Starting Application...
# Loaded model from disk
# 1/1 [==============================] - 0s 64ms/step
# 2222  ch1=+++++++++++++++++ 7 , 7
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 5 , 1
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 7 , 1
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 7 , 7
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 5 , 1
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 5 , 1
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 5 , 1
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 7 , 2
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 5 , 4
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 6ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 7 , 4
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 5
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 2 , 1
# True
# 1/1 [==============================] - 0s 6ms/step
# 2222  ch1=+++++++++++++++++ 2 , 5
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# True
# 1/1 [==============================] - 0s 6ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 19ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 27ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 5ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 2ms/step
# 2222  ch1=+++++++++++++++++ 2 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 4
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 4
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 24ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 4ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 1
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 22ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 5
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 22ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# False
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 7
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 5ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 2ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 6 , 3
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 6 , 3
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 6 , 6
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 4ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 507us/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 6ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 5
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 5
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 5
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 2ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 6ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 4ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 3
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 3
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 6 , 3
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 5
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 6ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 7 , 4
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 5ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 5ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 29ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 4ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 4ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# False
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# False
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# False
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# False
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 5ms/step
# 2222  ch1=+++++++++++++++++ 0 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 5ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# False
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 5ms/step
# 2222  ch1=+++++++++++++++++ 1 , 5
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 26ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 7 , 1
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 0 , 1
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 4ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 0 , 0
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 1ms/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 4
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 0 , 0
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 7 , 2
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 23ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# False
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# False
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# False
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 7 , 0
# True
# 1/1 [==============================] - 0s 29ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 0 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# Translating to: Tamil (ta)
# Original:   HELLO SARVESH
# Translated: வணக்கம் சேவேஷ்
# Translating to: Hindi (hi)
# Original:   HELLO SARVESH
# Translated: हैलो सेवेश
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 5 , 6
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 3 , 5
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 13ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 19ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# Translating to: English (en)
# Original:   HELLO SARVESH
# Translated:   HELLO SARVESH
# Translating to: French (fr)
# Original:   HELLO SARVESH
# Translated: Bonjour Sarvesh
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 7 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# True
# 1/1 [==============================] - 0s 6ms/step
# 2222  ch1=+++++++++++++++++ 7 , 2
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 4 , 5
# True
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 2
# False
# 1/1 [==============================] - 0s 20ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 5 , 1
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 24ms/step
# 2222  ch1=+++++++++++++++++ 2 , 5
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 6
# True
# ['Backspace', 'D', 'next', 'next', 'O', 'Backspace', 'Backspace', 'next', 'next', 'next']

# %%
# !pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from gtts) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from gtts) (8.1.7)
# Requirement already satisfied: colorama in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from click<8.2,>=7.1->gtts) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from requests<3,>=2.27->gtts) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from requests<3,>=2.27->gtts) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarve\anaconda3\envs\project\lib\site-packages (from requests<3,>=2.27->gtts) (2025.1.31)
# Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Installing collected packages: gtts
# Successfully installed gtts-2.5.4

# %%
# Importing Libraries
import numpy as np
import math
import cv2

import os, sys
import traceback
import pyttsx3
from keras.models import load_model
from cvzone.HandTrackingModule import HandDetector
from string import ascii_uppercase
import enchant
ddd=enchant.Dict("en-US")
hd = HandDetector(maxHands=1)
hd2 = HandDetector(maxHands=1)
import tkinter as tk
from PIL import Image, ImageTk
from googletrans import Translator


offset=29



class Application:

    def __init__(self):
        self.vs = cv2.VideoCapture(0)
        self.current_image = None
        self.model = load_model("D:\SEM8\Sign Language Project\Sign-language-text-translation-speech\Sign_language_model.h5")
        self.speak_engine=pyttsx3.init()
        self.speak_engine.setProperty("rate",100)
        voices=self.speak_engine.getProperty("voices")
        self.speak_engine.setProperty("voice",voices[0].id)


        self.ct = {}
        self.ct['blank'] = 0
        self.blank_flag = 0
        self.space_flag=False
        self.next_flag=True
        self.prev_char=""
        self.count=-1
        self.ten_prev_char=[]
        for i in range(10):
            self.ten_prev_char.append(" ")


        for i in ascii_uppercase:
            self.ct[i] = 0
        print("Loaded model from disk")


        self.root = tk.Tk()
        self.root.title("Sign Language To Text Conversion")
        self.root.protocol('WM_DELETE_WINDOW', self.destructor)
        self.root.geometry("1300x700")

        self.panel = tk.Label(self.root)
        self.panel.place(x=100, y=3, width=480, height=640)

        self.panel2 = tk.Label(self.root)  # initialize image panel
        self.panel2.place(x=700, y=115, width=400, height=400)

        self.T = tk.Label(self.root)
        self.T.place(x=60, y=5)
        self.T.config(text="Sign Language To Text Conversion", font=("Courier", 30, "bold"))

        self.panel3 = tk.Label(self.root)  # Current Symbol
        self.panel3.place(x=280, y=585)

        self.T1 = tk.Label(self.root)
        self.T1.place(x=10, y=580)
        self.T1.config(text="Character :", font=("Courier", 30, "bold"))

        self.panel5 = tk.Label(self.root)  # Sentence
        self.panel5.place(x=260, y=632)

        self.T3 = tk.Label(self.root)
        self.T3.place(x=10, y=632)
        self.T3.config(text="Sentence :", font=("Courier", 30, "bold"))

        self.T4 = tk.Label(self.root)
        self.T4.place(x=10, y=700)
        self.T4.config(text="Suggestions :", fg="red", font=("Courier", 30, "bold"))


        self.b1=tk.Button(self.root)
        self.b1.place(x=390,y=700)

        self.b2 = tk.Button(self.root)
        self.b2.place(x=590, y=700)

        self.b3 = tk.Button(self.root)
        self.b3.place(x=790, y=700)

        self.b4 = tk.Button(self.root)
        self.b4.place(x=990, y=700)

        self.speak = tk.Button(self.root)
        self.speak.place(x=1105, y=630)
        self.speak.config(text="Speak", font=("Courier", 20), wraplength=100, command=self.speak_fun)

        self.clear = tk.Button(self.root)
        self.clear.place(x=1005, y=630)
        self.clear.config(text="Clear", font=("Courier", 20), wraplength=100, command=self.clear_fun)

                # Dictionary of supported languages (key: language name, value: language code)
        self.languages = {
            "English": "en",
            "Tamil": "ta",
            "Hindi": "hi",
            "Telugu": "te",
            "Marathi": "mr",
            "Gujarati": "gu",
            "Bengali": "bn",
            "Kannada": "kn",
            "Malayalam": "ml",
            "Punjabi": "pa",
            "French": "fr",
            "Spanish": "es",
            "German": "de",
            "Russian": "ru",
            "Italian": "it",
            "Portuguese": "pt"
        }

        
        # Default selected language
        self.selected_language = tk.StringVar()
        self.selected_language.set("English")  # Default selection
        
        # Language selection dropdown
        self.language_menu = tk.OptionMenu(self.root, self.selected_language, *self.languages.keys())
        self.language_menu.config(font=("Courier", 15))
        self.language_menu.place(x=1405, y=630)  # Adjust position as needed

        self.translate_button = tk.Button(self.root, text="Translate", font=("Courier", 20), wraplength=150, command=self.translate_to_selected_language)
        self.translate_button.place(x=1205, y=630)  # Adjusted position


        self.str = " "
        self.ccc=0
        self.word = " "
        self.current_symbol = "C"
        self.photo = "Empty"
        self.original_text = ""  # Store original English text


        self.word1=" "
        self.word2 = " "
        self.word3 = " "
        self.word4 = " "

        self.video_loop()

    def translate_to_selected_language(self):
        from mtranslate import translate
    
        selected_lang = self.selected_language.get()  # Get selected language name
        lang_code = self.languages[selected_lang]  # Get language code
    
        print(f"Translating to: {selected_lang} ({lang_code})")  # Debug info
    
        try:
            # If English is selected, restore the original sentence
            if selected_lang == "English":
                self.str = self.original_text  # Restore original English text
            else:
                # Save original text only if translating from English
                if self.selected_language.get() == "Tamil" or self.str.isascii():
                    self.original_text = self.str  # Store the original English sentence
                
                translated_text = translate(self.str, lang_code, "auto")  # Auto-detect the source language
                self.str = translated_text  # Update translated text
    
            self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
    
            print(f"Original: {self.original_text}")
            print(f"Translated: {self.str}")
    
        except Exception as e:
            print("Translation Error:", str(e))
            self.panel5.config(text="Translation Failed", font=("Courier", 30), wraplength=1025)









    def video_loop(self):
        try:
            ok, frame = self.vs.read()
            cv2image = cv2.flip(frame, 1)
            if cv2image.any:
                hands = hd.findHands(cv2image, draw=False, flipType=True)
                cv2image_copy=np.array(cv2image)
                cv2image = cv2.cvtColor(cv2image, cv2.COLOR_BGR2RGB)
                self.current_image = Image.fromarray(cv2image)
                imgtk = ImageTk.PhotoImage(image=self.current_image)
                self.panel.imgtk = imgtk
                self.panel.config(image=imgtk)

                if hands[0]:
                    hand = hands[0]
                    map = hand[0]
                    x, y, w, h=map['bbox'] 
                    image = cv2image_copy[y - offset:y + h + offset, x - offset:x + w + offset]

                    white = cv2.imread("D:\SEM8\Sign Language Project\Sign-language-text-translation-speech\white.jpg")
                    # img_final=img_final1=img_final2=0
                    if image.all:
                        handz = hd2.findHands(image, draw=False, flipType=True)
                        self.ccc += 1
                        if handz[0]:
                            hand = handz[0]
                            handmap=hand[0]
                            self.pts = handmap['lmList']
                            # x1,y1,w1,h1=hand['bbox']

                            os = ((400 - w) // 2) - 15
                            os1 = ((400 - h) // 2) - 15
                            for t in range(0, 4, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(5, 8, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(9, 12, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(13, 16, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            for t in range(17, 20, 1):
                                cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                         (0, 255, 0), 3)
                            cv2.line(white, (self.pts[5][0] + os, self.pts[5][1] + os1), (self.pts[9][0] + os, self.pts[9][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[9][0] + os, self.pts[9][1] + os1), (self.pts[13][0] + os, self.pts[13][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[13][0] + os, self.pts[13][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1),
                                     (0, 255, 0), 3)
                            cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[5][0] + os, self.pts[5][1] + os1), (0, 255, 0),
                                     3)
                            cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1), (0, 255, 0),
                                     3)

                            for i in range(21):
                                cv2.circle(white, (self.pts[i][0] + os, self.pts[i][1] + os1), 2, (0, 0, 255), 1)

                            res=white
                            self.predict(res)

                            self.current_image2 = Image.fromarray(res)

                            imgtk = ImageTk.PhotoImage(image=self.current_image2)

                            self.panel2.imgtk = imgtk
                            self.panel2.config(image=imgtk)

                            self.panel3.config(text=self.current_symbol, font=("Courier", 30))

                            #self.panel4.config(text=self.word, font=("Courier", 30))



                            self.b1.config(text=self.word1, font=("Courier", 20), wraplength=825, command=self.action1)
                            self.b2.config(text=self.word2, font=("Courier", 20), wraplength=825,  command=self.action2)
                            self.b3.config(text=self.word3, font=("Courier", 20), wraplength=825,  command=self.action3)
                            self.b4.config(text=self.word4, font=("Courier", 20), wraplength=825,  command=self.action4)

                self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
        except Exception:
            print(Exception.__traceback__)
            hands = hd.findHands(cv2image, draw=False, flipType=True)
            cv2image_copy=np.array(cv2image)
            cv2image = cv2.cvtColor(cv2image, cv2.COLOR_BGR2RGB)
            self.current_image = Image.fromarray(cv2image)
            imgtk = ImageTk.PhotoImage(image=self.current_image)
            self.panel.imgtk = imgtk
            self.panel.config(image=imgtk)

            if hands:
                # #print(" --------- lmlist=",hands[1])
                hand = hands[0]
                x, y, w, h = hand['bbox']
                image = cv2image_copy[y - offset:y + h + offset, x - offset:x + w + offset]

                white = cv2.imread("D:\SEM8\Sign Language Project\Sign-language-text-translation-speech\white.jpg")
                # img_final=img_final1=img_final2=0

                handz = hd2.findHands(image, draw=False, flipType=True)
                print(" ", self.ccc)
                self.ccc += 1
                if handz:
                    hand = handz[0]
                    self.pts = hand['lmList']
                    # x1,y1,w1,h1=hand['bbox']

                    os = ((400 - w) // 2) - 15
                    os1 = ((400 - h) // 2) - 15
                    for t in range(0, 4, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(5, 8, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(9, 12, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(13, 16, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    for t in range(17, 20, 1):
                        cv2.line(white, (self.pts[t][0] + os, self.pts[t][1] + os1), (self.pts[t + 1][0] + os, self.pts[t + 1][1] + os1),
                                 (0, 255, 0), 3)
                    cv2.line(white, (self.pts[5][0] + os, self.pts[5][1] + os1), (self.pts[9][0] + os, self.pts[9][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[9][0] + os, self.pts[9][1] + os1), (self.pts[13][0] + os, self.pts[13][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[13][0] + os, self.pts[13][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1),
                             (0, 255, 0), 3)
                    cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[5][0] + os, self.pts[5][1] + os1), (0, 255, 0),
                             3)
                    cv2.line(white, (self.pts[0][0] + os, self.pts[0][1] + os1), (self.pts[17][0] + os, self.pts[17][1] + os1), (0, 255, 0),
                             3)

                    for i in range(21):
                        cv2.circle(white, (self.pts[i][0] + os, self.pts[i][1] + os1), 2, (0, 0, 255), 1)

                    res=white
                    self.predict(res)

                    self.current_image2 = Image.fromarray(res)

                    imgtk = ImageTk.PhotoImage(image=self.current_image2)

                    self.panel2.imgtk = imgtk
                    self.panel2.config(image=imgtk)

                    self.panel3.config(text=self.current_symbol, font=("Courier", 30))

                    #self.panel4.config(text=self.word, font=("Courier", 30))



                    self.b1.config(text=self.word1, font=("Courier", 20), wraplength=825, command=self.action1)
                    self.b2.config(text=self.word2, font=("Courier", 20), wraplength=825,  command=self.action2)
                    self.b3.config(text=self.word3, font=("Courier", 20), wraplength=825,  command=self.action3)
                    self.b4.config(text=self.word4, font=("Courier", 20), wraplength=825,  command=self.action4)

            self.panel5.config(text=self.str, font=("Courier", 30), wraplength=1025)
        except Exception:
            print("==", traceback.format_exc())
        finally:
            self.root.after(1, self.video_loop)

    def distance(self,x,y):
        return math.sqrt(((x[0] - y[0]) ** 2) + ((x[1] - y[1]) ** 2))

    def action1(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word1.upper()


    def action2(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str=self.str[:idx_word]
        self.str=self.str+self.word2.upper()
        #self.str[idx_word:last_idx] = self.word2


    def action3(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word3.upper()



    def action4(self):
        idx_space = self.str.rfind(" ")
        idx_word = self.str.find(self.word, idx_space)
        last_idx = len(self.str)
        self.str = self.str[:idx_word]
        self.str = self.str + self.word4.upper()


    def speak_fun(self):
        from gtts import gTTS
        import os
        import tempfile
        import pygame
    
        selected_lang = self.selected_language.get()  # Get selected language name
        lang_code = self.languages[selected_lang]  # Get language code
    
        print(f"Speaking in: {selected_lang} ({lang_code})")  # Debugging output
    
        try:
            # Convert text to speech
            tts = gTTS(text=self.str, lang=lang_code, slow=False)
    
            # Save to a temporary file
            temp_audio = tempfile.NamedTemporaryFile(delete=False, suffix=".mp3")
            temp_path = temp_audio.name
            temp_audio.close()  # Close the file so it can be used
    
            tts.save(temp_path)  # Save generated speech
    
            # Play the audio using pygame
            pygame.mixer.init()
            pygame.mixer.music.load(temp_path)
            pygame.mixer.music.play()
    
            # Wait for the audio to finish playing
            while pygame.mixer.music.get_busy():
                continue
    
            os.remove(temp_path)  # Delete the temp file after playing
    
        except Exception as e:
            print("Speech Error:", str(e))





    def clear_fun(self):
        self.str=" "
        self.word1 = " "
        self.word2 = " "
        self.word3 = " "
        self.word4 = " "

    def predict(self, test_image):
        white=test_image
        white = white.reshape(1, 400, 400, 3)
        prob = np.array(self.model.predict(white)[0], dtype='float32')
        ch1 = np.argmax(prob, axis=0)
        prob[ch1] = 0
        ch2 = np.argmax(prob, axis=0)
        prob[ch2] = 0
        ch3 = np.argmax(prob, axis=0)
        prob[ch3] = 0

        pl = [ch1, ch2]

        # condition for [Aemnst]
        l = [[5, 2], [5, 3], [3, 5], [3, 6], [3, 0], [3, 2], [6, 4], [6, 1], [6, 2], [6, 6], [6, 7], [6, 0], [6, 5],
             [4, 1], [1, 0], [1, 1], [6, 3], [1, 6], [5, 6], [5, 1], [4, 5], [1, 4], [1, 5], [2, 0], [2, 6], [4, 6],
             [1, 0], [5, 7], [1, 6], [6, 1], [7, 6], [2, 5], [7, 1], [5, 4], [7, 0], [7, 5], [7, 2]]
        if pl in l:
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 0

        # condition for [o][s]
        l = [[2, 2], [2, 1]]
        if pl in l:
            if (self.pts[5][0] < self.pts[4][0]):
                ch1 = 0
                print("++++++++++++++++++")
                # print("00000")

        # condition for [c0][aemnst]
        l = [[0, 0], [0, 6], [0, 2], [0, 5], [0, 1], [0, 7], [5, 2], [7, 6], [7, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[4][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][
                0] and self.pts[0][0] > self.pts[20][0]) and self.pts[5][0] > self.pts[4][0]:
                ch1 = 2

        # condition for [c0][aemnst]
        l = [[6, 0], [6, 6], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[8], self.pts[16]) < 52:
                ch1 = 2


        # condition for [gh][bdfikruvw]
        l = [[1, 4], [1, 5], [1, 6], [1, 3], [1, 0]]
        pl = [ch1, ch2]

        if pl in l:
            if self.pts[6][1] > self.pts[8][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][1] and self.pts[0][0] < self.pts[8][
                0] and self.pts[0][0] < self.pts[12][0] and self.pts[0][0] < self.pts[16][0] and self.pts[0][0] < self.pts[20][0]:
                ch1 = 3



        # con for [gh][l]
        l = [[4, 6], [4, 1], [4, 5], [4, 3], [4, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][0] > self.pts[0][0]:
                ch1 = 3

        # con for [gh][pqz]
        l = [[5, 3], [5, 0], [5, 7], [5, 4], [5, 2], [5, 1], [5, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[2][1] + 15 < self.pts[16][1]:
                ch1 = 3

        # con for [l][x]
        l = [[6, 4], [6, 1], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[4], self.pts[11]) > 55:
                ch1 = 4

        # con for [l][d]
        l = [[1, 4], [1, 6], [1, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.distance(self.pts[4], self.pts[11]) > 50) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 4

        # con for [l][gh]
        l = [[3, 6], [3, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[4][0] < self.pts[0][0]):
                ch1 = 4

        # con for [l][c0]
        l = [[2, 2], [2, 5], [2, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[1][0] < self.pts[12][0]):
                ch1 = 4

        # con for [l][c0]
        l = [[2, 2], [2, 5], [2, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[1][0] < self.pts[12][0]):
                ch1 = 4

        # con for [gh][z]
        l = [[3, 6], [3, 5], [3, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]) and self.pts[4][1] > self.pts[10][1]:
                ch1 = 5

        # con for [gh][pq]
        l = [[3, 2], [3, 1], [3, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][1] + 17 > self.pts[8][1] and self.pts[4][1] + 17 > self.pts[12][1] and self.pts[4][1] + 17 > self.pts[16][1] and self.pts[4][
                1] + 17 > self.pts[20][1]:
                ch1 = 5

        # con for [l][pqz]
        l = [[4, 4], [4, 5], [4, 2], [7, 5], [7, 6], [7, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[4][0] > self.pts[0][0]:
                ch1 = 5

        # con for [pqz][aemnst]
        l = [[0, 2], [0, 6], [0, 1], [0, 5], [0, 0], [0, 7], [0, 4], [0, 3], [2, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[0][0] < self.pts[8][0] and self.pts[0][0] < self.pts[12][0] and self.pts[0][0] < self.pts[16][0] and self.pts[0][0] < self.pts[20][0]:
                ch1 = 5

        # con for [pqz][yj]
        l = [[5, 7], [5, 2], [5, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[3][0] < self.pts[0][0]:
                ch1 = 7

        # con for [l][yj]
        l = [[4, 6], [4, 2], [4, 4], [4, 1], [4, 5], [4, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[6][1] < self.pts[8][1]:
                ch1 = 7

        # con for [x][yj]
        l = [[6, 7], [0, 7], [0, 1], [0, 0], [6, 4], [6, 6], [6, 5], [6, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[18][1] > self.pts[20][1]:
                ch1 = 7

        # condition for [x][aemnst]
        l = [[0, 4], [0, 2], [0, 3], [0, 1], [0, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] > self.pts[16][0]:
                ch1 = 6


        # condition for [yj][x]
        print("2222  ch1=+++++++++++++++++", ch1, ",", ch2)
        l = [[7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[18][1] < self.pts[20][1] and self.pts[8][1] < self.pts[10][1]:
                ch1 = 6

        # condition for [c0][x]
        l = [[2, 1], [2, 2], [2, 6], [2, 7], [2, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[8], self.pts[16]) > 50:
                ch1 = 6

        # con for [l][x]

        l = [[4, 6], [4, 2], [4, 1], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if self.distance(self.pts[4], self.pts[11]) < 60:
                ch1 = 6

        # con for [x][d]
        l = [[1, 4], [1, 6], [1, 0], [1, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] - self.pts[4][0] - 15 > 0:
                ch1 = 6

        # con for [b][pqz]
        l = [[5, 0], [5, 1], [5, 4], [5, 5], [5, 6], [6, 1], [7, 6], [0, 2], [7, 1], [7, 4], [6, 6], [7, 2], [5, 0],
             [6, 3], [6, 4], [7, 5], [7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 1

        # con for [f][pqz]
        l = [[6, 1], [6, 0], [0, 3], [6, 4], [2, 2], [0, 6], [6, 2], [7, 6], [4, 6], [4, 1], [4, 2], [0, 2], [7, 1],
             [7, 4], [6, 6], [7, 2], [7, 5], [7, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and
                    self.pts[18][1] > self.pts[20][1]):
                ch1 = 1

        l = [[6, 1], [6, 0], [4, 2], [4, 1], [4, 6], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and
                    self.pts[18][1] > self.pts[20][1]):
                ch1 = 1

        # con for [d][pqz]
        fg = 19
        # print("_________________ch1=",ch1," ch2=",ch2)
        l = [[5, 0], [3, 4], [3, 0], [3, 1], [3, 5], [5, 5], [5, 4], [5, 1], [7, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1]) and (self.pts[2][0] < self.pts[0][0]) and self.pts[4][1] > self.pts[14][1]):
                ch1 = 1

        l = [[4, 1], [4, 2], [4, 4]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.distance(self.pts[4], self.pts[11]) < 50) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 1

        l = [[3, 4], [3, 0], [3, 1], [3, 5], [3, 6]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1]) and (self.pts[2][0] < self.pts[0][0]) and self.pts[14][1] < self.pts[4][1]):
                ch1 = 1

        l = [[6, 6], [6, 4], [6, 1], [6, 2]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[5][0] - self.pts[4][0] - 15 < 0:
                ch1 = 1

        # con for [i][pqz]
        l = [[5, 4], [5, 5], [5, 1], [0, 3], [0, 7], [5, 0], [0, 2], [6, 2], [7, 5], [7, 1], [7, 6], [7, 7]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] > self.pts[20][1])):
                ch1 = 1

        # con for [yj][bfdi]
        l = [[1, 5], [1, 7], [1, 1], [1, 6], [1, 3], [1, 0]]
        pl = [ch1, ch2]
        if pl in l:
            if (self.pts[4][0] < self.pts[5][0] + 15) and (
            (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
             self.pts[18][1] > self.pts[20][1])):
                ch1 = 7

        # con for [uvr]
        l = [[5, 5], [5, 0], [5, 4], [5, 1], [4, 6], [4, 1], [7, 6], [3, 0], [3, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if ((self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and
                 self.pts[18][1] < self.pts[20][1])) and self.pts[4][1] > self.pts[14][1]:
                ch1 = 1

        # con for [w]
        fg = 13
        l = [[3, 5], [3, 0], [3, 6], [5, 1], [4, 1], [2, 0], [5, 0], [5, 5]]
        pl = [ch1, ch2]
        if pl in l:
            if not (self.pts[0][0] + fg < self.pts[8][0] and self.pts[0][0] + fg < self.pts[12][0] and self.pts[0][0] + fg < self.pts[16][0] and
                    self.pts[0][0] + fg < self.pts[20][0]) and not (
                    self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][0] and self.pts[0][0] > self.pts[20][
                0]) and self.distance(self.pts[4], self.pts[11]) < 50:
                ch1 = 1

        # con for [w]

        l = [[5, 0], [5, 5], [0, 1]]
        pl = [ch1, ch2]
        if pl in l:
            if self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1]:
                ch1 = 1

        # -------------------------condn for 8 groups  ends

        # -------------------------condn for subgroups  starts
        #
        if ch1 == 0:
            ch1 = 'S'
            if self.pts[4][0] < self.pts[6][0] and self.pts[4][0] < self.pts[10][0] and self.pts[4][0] < self.pts[14][0] and self.pts[4][0] < self.pts[18][0]:
                ch1 = 'A'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] < self.pts[10][0] and self.pts[4][0] < self.pts[14][0] and self.pts[4][0] < self.pts[18][
                0] and self.pts[4][1] < self.pts[14][1] and self.pts[4][1] < self.pts[18][1]:
                ch1 = 'T'
            if self.pts[4][1] > self.pts[8][1] and self.pts[4][1] > self.pts[12][1] and self.pts[4][1] > self.pts[16][1] and self.pts[4][1] > self.pts[20][1]:
                ch1 = 'E'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] > self.pts[10][0] and self.pts[4][0] > self.pts[14][0] and self.pts[4][1] < self.pts[18][1]:
                ch1 = 'M'
            if self.pts[4][0] > self.pts[6][0] and self.pts[4][0] > self.pts[10][0] and self.pts[4][1] < self.pts[18][1] and self.pts[4][1] < self.pts[14][1]:
                ch1 = 'N'

        if ch1 == 2:
            if self.distance(self.pts[12], self.pts[4]) > 42:
                ch1 = 'C'
            else:
                ch1 = 'O'

        if ch1 == 3:
            if (self.distance(self.pts[8], self.pts[12])) > 72:
                ch1 = 'G'
            else:
                ch1 = 'H'

        if ch1 == 7:
            if self.distance(self.pts[8], self.pts[4]) > 42:
                ch1 = 'Y'
            else:
                ch1 = 'J'

        if ch1 == 4:
            ch1 = 'L'

        if ch1 == 6:
            ch1 = 'X'

        if ch1 == 5:
            if self.pts[4][0] > self.pts[12][0] and self.pts[4][0] > self.pts[16][0] and self.pts[4][0] > self.pts[20][0]:
                if self.pts[8][1] < self.pts[5][1]:
                    ch1 = 'Z'
                else:
                    ch1 = 'Q'
            else:
                ch1 = 'P'

        if ch1 == 1:
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'B'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 'D'
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'F'
            if (self.pts[6][1] < self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] > self.pts[20][
                1]):
                ch1 = 'I'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]):
                ch1 = 'W'
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] < self.pts[20][
                1]) and self.pts[4][1] < self.pts[9][1]:
                ch1 = 'K'
            if ((self.distance(self.pts[8], self.pts[12]) - self.distance(self.pts[6], self.pts[10])) < 8) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 'U'
            if ((self.distance(self.pts[8], self.pts[12]) - self.distance(self.pts[6], self.pts[10])) >= 8) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]) and (self.pts[4][1] > self.pts[9][1]):
                ch1 = 'V'

            if (self.pts[8][0] > self.pts[12][0]) and (
                    self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] <
                    self.pts[20][1]):
                ch1 = 'R'

        if ch1 == 1 or ch1 =='E' or ch1 =='S' or ch1 =='X' or ch1 =='Y' or ch1 =='B':
            if (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] < self.pts[12][1] and self.pts[14][1] < self.pts[16][1] and self.pts[18][1] > self.pts[20][1]):
                ch1=" "



        print(self.pts[4][0] < self.pts[5][0])
        if ch1 == 'E' or ch1=='Y' or ch1=='B':
            if (self.pts[4][0] < self.pts[5][0]) and (self.pts[6][1] > self.pts[8][1] and self.pts[10][1] > self.pts[12][1] and self.pts[14][1] > self.pts[16][1] and self.pts[18][1] > self.pts[20][1]):
                ch1="next"


        if ch1 == 'Next' or 'B' or 'C' or 'H' or 'F' or 'X':
            if (self.pts[0][0] > self.pts[8][0] and self.pts[0][0] > self.pts[12][0] and self.pts[0][0] > self.pts[16][0] and self.pts[0][0] > self.pts[20][0]) and (self.pts[4][1] < self.pts[8][1] and self.pts[4][1] < self.pts[12][1] and self.pts[4][1] < self.pts[16][1] and self.pts[4][1] < self.pts[20][1]) and (self.pts[4][1] < self.pts[6][1] and self.pts[4][1] < self.pts[10][1] and self.pts[4][1] < self.pts[14][1] and self.pts[4][1] < self.pts[18][1]):
                ch1 = 'Backspace'


        if ch1=="next" and self.prev_char!="next":
            if self.ten_prev_char[(self.count-2)%10]!="next":
                if self.ten_prev_char[(self.count-2)%10]=="Backspace":
                    self.str=self.str[0:-1]
                else:
                    if self.ten_prev_char[(self.count - 2) % 10] != "Backspace":
                        self.str = self.str + self.ten_prev_char[(self.count-2)%10]
            else:
                if self.ten_prev_char[(self.count - 0) % 10] != "Backspace":
                    self.str = self.str + self.ten_prev_char[(self.count - 0) % 10]


        if ch1=="  " and self.prev_char!="  ":
            self.str = self.str + "  "

        self.prev_char=ch1
        self.current_symbol=ch1
        self.count += 1
        self.ten_prev_char[self.count%10]=ch1


        if len(self.str.strip())!=0:
            st=self.str.rfind(" ")
            ed=len(self.str)
            word=self.str[st+1:ed]
            self.word=word
            if len(word.strip())!=0:
                ddd.check(word)
                lenn = len(ddd.suggest(word))
                if lenn >= 4:
                    self.word4 = ddd.suggest(word)[3]

                if lenn >= 3:
                    self.word3 = ddd.suggest(word)[2]

                if lenn >= 2:
                    self.word2 = ddd.suggest(word)[1]

                if lenn >= 1:
                    self.word1 = ddd.suggest(word)[0]
            else:
                self.word1 = " "
                self.word2 = " "
                self.word3 = " "
                self.word4 = " "


    def destructor(self):
        print(self.ten_prev_char)
        self.root.destroy()
        self.vs.release()
        cv2.destroyAllWindows()


print("Starting Application...")

(Application()).root.mainloop()
# Out:
# Starting Application...
# Loaded model from disk
# 1/1 [==============================] - 0s 66ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# False
# 1/1 [==============================] - 0s 19ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 25ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 2ms/step
# 2222  ch1=+++++++++++++++++ 3 , 5
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 3 , 5
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 4ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 3ms/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 3 , 0
# True
# 1/1 [==============================] - 0s 24ms/step
# 2222  ch1=+++++++++++++++++ 3 , 7
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 7 , 7
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 7 , 7
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 0 , 7
# False
# 1/1 [==============================] - 0s 11ms/step
# 2222  ch1=+++++++++++++++++ 7 , 7
# False
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 0 , 7
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 7
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 7ms/step
# 2222  ch1=+++++++++++++++++ 0 , 7
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 31ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 2 , 0
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 1 , 4
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 4 , 4
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 4 , 2
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 5ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 10ms/step
# 2222  ch1=+++++++++++++++++ 0 , 3
# True
# 1/1 [==============================] - 0s 25ms/step
# 2222  ch1=+++++++++++++++++ 0 , 6
# True
# 1/1 [==============================] - 0s 8ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 9ms/step
# 2222  ch1=+++++++++++++++++ 0 , 2
# True
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 1ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 12ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 19ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 2 , 6
# True
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# True
# 1/1 [==============================] - 0s 0s/step
# 2222  ch1=+++++++++++++++++ 1 , 6
# True
# pygame 2.6.1 (SDL 2.28.4, Python 3.9.21)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Speaking in: English (en)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmpjkz3v5kj.mp3'
# Speaking in: Tamil (ta)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmppm82o7sc.mp3'
# Translating to: Tamil (ta)
# Original:  HELLO
# Translated: வணக்கம்
# Speaking in: Tamil (ta)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmpzj6crz4y.mp3'
# Translating to: Gujarati (gu)
# Original:  HELLO
# Translated: એક
# Speaking in: Gujarati (gu)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmpapccn39a.mp3'
# Speaking in: Italian (it)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmpjueoklqf.mp3'
# Translating to: English (en)
# Original:  HELLO
# Translated:  HELLO
# Speaking in: English (en)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmphfnv4aek.mp3'
# Speaking in: Tamil (ta)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmplijkaojs.mp3'
# Translating to: Tamil (ta)
# Original:  HELLO
# Translated: வணக்கம்
# Translating to: Tamil (ta)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: Tamil (ta)
# Original: வணக்கம்
# Translated: வணக்கம்
# Speaking in: Tamil (ta)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmppik_644b.mp3'
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Speaking in: English (en)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmpiuabxpzf.mp3'
# Translating to: Marathi (mr)
# Original: வணக்கம்
# Translated: नी
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# Speaking in: English (en)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmpzrqd0uje.mp3'
# Translating to: English (en)
# Original: வணக்கம்
# Translated: வணக்கம்
# 1/1 [==============================] - 0s 25ms/step
# 2222  ch1=+++++++++++++++++ 4 , 1
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 3 , 3
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 5 , 2
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 5 , 6
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 3 , 5
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 5 , 1
# False
# 1/1 [==============================] - 0s 27ms/step
# 2222  ch1=+++++++++++++++++ 5 , 6
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 3 , 5
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 3 , 1
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 5 , 4
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 5 , 4
# False
# 1/1 [==============================] - 0s 14ms/step
# 2222  ch1=+++++++++++++++++ 6 , 4
# False
# 1/1 [==============================] - 0s 16ms/step
# 2222  ch1=+++++++++++++++++ 5 , 6
# False
# 1/1 [==============================] - 0s 17ms/step
# 2222  ch1=+++++++++++++++++ 3 , 2
# False
# 1/1 [==============================] - 0s 15ms/step
# 2222  ch1=+++++++++++++++++ 5 , 3
# False
# 1/1 [==============================] - 0s 18ms/step
# 2222  ch1=+++++++++++++++++ 7 , 2
# True
# Speaking in: English (en)
# Speech Error: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\sarve\\AppData\\Local\\Temp\\tmp3e_e2q4l.mp3'
# ['P', 'D', 'P', 'H', 'P', 'next', 'H', 'D', 'H', 'P']
